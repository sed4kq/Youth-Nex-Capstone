# %% [markdown]
# ## Text Extraction

# %%
# !pip install -q pymupdf python-docx pandas

# !pip install reportlab

# !apt-get update -qq
# !apt-get install -y -qq libreoffice

# !soffice --version
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 69.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 21.1 MB/s eta 0:00:00
# Collecting reportlab
#   Downloading reportlab-4.4.10-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab) (11.3.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab) (3.4.7)
# Downloading reportlab-4.4.10-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.1 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.10
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-opensymbol.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../000-fonts-opensymbol_2%3a102.12+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-style-colibre.
# Preparing to unpack .../001-libreoffice-style-colibre_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-sal3.
# Preparing to unpack .../002-libuno-sal3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-sal3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-salhelpergcc3-3.
# Preparing to unpack .../003-libuno-salhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-cppu3.
# Preparing to unpack .../004-libuno-cppu3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package uno-libs-private.
# Preparing to unpack .../005-uno-libs-private_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking uno-libs-private (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package liblangtag-common.
# Preparing to unpack .../006-liblangtag-common_0.6.3-2ubuntu1_all.deb ...
# Unpacking liblangtag-common (0.6.3-2ubuntu1) ...
# Selecting previously unselected package liblangtag1:amd64.
# Preparing to unpack .../007-liblangtag1_0.6.3-2ubuntu1_amd64.deb ...
# Unpacking liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Selecting previously unselected package libuno-cppuhelpergcc3-3.
# Preparing to unpack .../008-libuno-cppuhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libuno-purpenvhelpergcc3-3.
# Preparing to unpack .../009-libuno-purpenvhelpergcc3-3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package ure.
# Preparing to unpack .../010-ure_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking ure (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-common.
# Preparing to unpack .../011-libreoffice-common_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../012-libabsl20210324_0~20210324.2-2ubuntu0.3_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2ubuntu0.3) ...
# Selecting previously unselected package libboost-thread1.74.0:amd64.
# Preparing to unpack .../013-libboost-thread1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-locale1.74.0:amd64.
# Preparing to unpack .../014-libboost-locale1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-locale1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libclucene-core1v5:amd64.
# Preparing to unpack .../015-libclucene-core1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libclucene-contribs1v5:amd64.
# Preparing to unpack .../016-libclucene-contribs1v5_2.3.3.4+dfsg-1ubuntu5_amd64.deb ...
# Unpacking libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Selecting previously unselected package libeot0:amd64.
# Preparing to unpack .../017-libeot0_0.01-5build2_amd64.deb ...
# Unpacking libeot0:amd64 (0.01-5build2) ...
# Selecting previously unselected package libexttextcat-data.
# Preparing to unpack .../018-libexttextcat-data_3.4.5-1build2_all.deb ...
# Unpacking libexttextcat-data (3.4.5-1build2) ...
# Selecting previously unselected package libexttextcat-2.0-0:amd64.
# Preparing to unpack .../019-libexttextcat-2.0-0_3.4.5-1build2_amd64.deb ...
# Unpacking libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../020-libgpgme11_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package libgpgmepp6:amd64.
# Preparing to unpack .../021-libgpgmepp6_1.16.0-1.2ubuntu4.2_amd64.deb ...
# Unpacking libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../022-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../023-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../024-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../025-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../026-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libmythes-1.2-0:amd64.
# Preparing to unpack .../027-libmythes-1.2-0_2%3a1.2.4-4build1_amd64.deb ...
# Unpacking libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Selecting previously unselected package libboost-filesystem1.74.0:amd64.
# Preparing to unpack .../028-libboost-filesystem1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-filesystem1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-iostreams1.74.0:amd64.
# Preparing to unpack .../029-libboost-iostreams1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package liborcus-parser-0.17-0:amd64.
# Preparing to unpack .../030-liborcus-parser-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package liborcus-0.17-0:amd64.
# Preparing to unpack .../031-liborcus-0.17-0_0.17.2-2_amd64.deb ...
# Unpacking liborcus-0.17-0:amd64 (0.17.2-2) ...
# Selecting previously unselected package libyajl2:amd64.
# Preparing to unpack .../032-libyajl2_2.1.0-3ubuntu0.22.04.1_amd64.deb ...
# Unpacking libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Selecting previously unselected package libraptor2-0:amd64.
# Preparing to unpack .../033-libraptor2-0_2.0.15-0ubuntu4.1_amd64.deb ...
# Unpacking libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Selecting previously unselected package libmhash2:amd64.
# Preparing to unpack .../034-libmhash2_0.9.9.9-9build2_amd64.deb ...
# Unpacking libmhash2:amd64 (0.9.9.9-9build2) ...
# Selecting previously unselected package librasqal3:amd64.
# Preparing to unpack .../035-librasqal3_0.9.33-0.2ubuntu1_amd64.deb ...
# Unpacking librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Selecting previously unselected package librdf0:amd64.
# Preparing to unpack .../036-librdf0_1.0.17-1.1ubuntu3_amd64.deb ...
# Unpacking librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../037-librevenge-0.0-0_0.0.4-6ubuntu7_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Selecting previously unselected package libxmlsec1:amd64.
# Preparing to unpack .../038-libxmlsec1_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libxmlsec1-nss:amd64.
# Preparing to unpack .../039-libxmlsec1-nss_1.2.33-1build2_amd64.deb ...
# Unpacking libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Selecting previously unselected package libreoffice-core.
# Preparing to unpack .../040-libreoffice-core_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-base-core.
# Preparing to unpack .../041-libreoffice-base-core_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-base-drivers.
# Preparing to unpack .../042-libreoffice-base-drivers_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-base.
# Preparing to unpack .../043-libreoffice-base_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/dialog.xlc to /usr/lib/libreoffice/share/basic/dialog.xlc.noaccess by libreoffice-base', none removed.
# No diversion 'diversion of /usr/lib/libreoffice/share/basic/script.xlc to /usr/lib/libreoffice/share/basic/script.xlc.noaccess by libreoffice-base', none removed.
# Unpacking libreoffice-base (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../044-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../045-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../046-apparmor_3.0.4-2ubuntu2.5_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.5) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../047-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../048-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../049-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../050-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../051-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package openjdk-11-jre-headless:amd64.
# Preparing to unpack .../052-openjdk-11-jre-headless_11.0.30+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../053-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../054-openjdk-11-jre_11.0.30+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../055-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../056-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package firebird3.0-common-doc.
# Preparing to unpack .../057-firebird3.0-common-doc_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-common.
# Preparing to unpack .../058-firebird3.0-common_3.0.8.33535.ds4-1ubuntu2_all.deb ...
# Unpacking firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libtommath1:amd64.
# Preparing to unpack .../059-libtommath1_1.2.0-6ubuntu0.22.04.1_amd64.deb ...
# Unpacking libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Selecting previously unselected package libfbclient2:amd64.
# Preparing to unpack .../060-libfbclient2_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package libib-util:amd64.
# Preparing to unpack .../061-libib-util_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-server-core:amd64.
# Preparing to unpack .../062-firebird3.0-server-core_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package firebird3.0-utils.
# Preparing to unpack .../063-firebird3.0-utils_3.0.8.33535.ds4-1ubuntu2_amd64.deb ...
# Unpacking firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../064-fonts-crosextra-caladea_20130214-2.1_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2.1) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../065-fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../066-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../067-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../068-fonts-dejavu_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu (2.37-2build1) ...
# Selecting previously unselected package fonts-liberation2.
# Preparing to unpack .../069-fonts-liberation2_2.1.5-1_all.deb ...
# Unpacking fonts-liberation2 (2.1.5-1) ...
# Selecting previously unselected package fonts-linuxlibertine.
# Preparing to unpack .../070-fonts-linuxlibertine_5.3.0-6_all.deb ...
# Unpacking fonts-linuxlibertine (5.3.0-6) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../071-fonts-noto-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-core (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-extra.
# Preparing to unpack .../072-fonts-noto-extra_20201225-1build1_all.deb ...
# Unpacking fonts-noto-extra (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../073-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-noto-ui-core.
# Preparing to unpack .../074-fonts-noto-ui-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-ui-core (20201225-1build1) ...
# Selecting previously unselected package fonts-sil-gentium.
# Preparing to unpack .../075-fonts-sil-gentium_20081126%3a1.03-4_all.deb ...
# Unpacking fonts-sil-gentium (20081126:1.03-4) ...
# Selecting previously unselected package fonts-sil-gentium-basic.
# Preparing to unpack .../076-fonts-sil-gentium-basic_1.102-1.1_all.deb ...
# Unpacking fonts-sil-gentium-basic (1.102-1.1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../077-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../078-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../079-gstreamer1.0-gl_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../080-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../081-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../082-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../083-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../084-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../085-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package gstreamer1.0-gtk3:amd64.
# Preparing to unpack .../086-gstreamer1.0-gtk3_1.20.3-0ubuntu1.5_amd64.deb ...
# Unpacking gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.5) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../087-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../088-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../089-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../090-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabw-0.1-1:amd64.
# Preparing to unpack .../091-libabw-0.1-1_0.1.3-1build3_amd64.deb ...
# Unpacking libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../092-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../093-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../094-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../095-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libbsh-java.
# Preparing to unpack .../096-libbsh-java_2.0b4-20_all.deb ...
# Unpacking libbsh-java (2.0b4-20) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../097-libcdr-0.1-1_0.1.6-2build2_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../098-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../099-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libe-book-0.1-1:amd64.
# Preparing to unpack .../100-libe-book-0.1-1_0.1.3-2build2_amd64.deb ...
# Unpacking libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Selecting previously unselected package libel-api-java.
# Preparing to unpack .../101-libel-api-java_3.0.0-3_all.deb ...
# Unpacking libel-api-java (3.0.0-3) ...
# Selecting previously unselected package libepubgen-0.1-1:amd64.
# Preparing to unpack .../102-libepubgen-0.1-1_0.1.1-1ubuntu5_amd64.deb ...
# Unpacking libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Selecting previously unselected package libetonyek-0.1-1:amd64.
# Preparing to unpack .../103-libetonyek-0.1-1_0.1.10-3build1_amd64.deb ...
# Unpacking libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Selecting previously unselected package libfreehand-0.1-1.
# Preparing to unpack .../104-libfreehand-0.1-1_0.1.2-3build2_amd64.deb ...
# Unpacking libfreehand-0.1-1 (0.1.2-3build2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../105-libgtk-3-bin_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libservlet-api-java.
# Preparing to unpack .../106-libservlet-api-java_4.0.1-2_all.deb ...
# Unpacking libservlet-api-java (4.0.1-2) ...
# Selecting previously unselected package libjsp-api-java.
# Preparing to unpack .../107-libjsp-api-java_2.3.4-3_all.deb ...
# Unpacking libjsp-api-java (2.3.4-3) ...
# Selecting previously unselected package libwebsocket-api-java.
# Preparing to unpack .../108-libwebsocket-api-java_1.1-2_all.deb ...
# Unpacking libwebsocket-api-java (1.1-2) ...
# Selecting previously unselected package libservlet3.1-java.
# Preparing to unpack .../109-libservlet3.1-java_1%3a4.0.1-2_all.deb ...
# Unpacking libservlet3.1-java (1:4.0.1-2) ...
# Selecting previously unselected package libhsqldb1.8.0-java.
# Preparing to unpack .../110-libhsqldb1.8.0-java_1.8.0.10+dfsg-11_all.deb ...
# Unpacking libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Selecting previously unselected package libunoloader-java.
# Preparing to unpack .../111-libunoloader-java_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libunoloader-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package ure-java.
# Preparing to unpack .../112-ure-java_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking ure-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package liblibreoffice-java.
# Preparing to unpack .../113-liblibreoffice-java_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libmspub-0.1-1:amd64.
# Preparing to unpack .../114-libmspub-0.1-1_0.1.4-3build3_amd64.deb ...
# Unpacking libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Selecting previously unselected package libmwaw-0.3-3:amd64.
# Preparing to unpack .../115-libmwaw-0.3-3_0.3.21-1build1_amd64.deb ...
# Unpacking libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Selecting previously unselected package libodfgen-0.1-1:amd64.
# Preparing to unpack .../116-libodfgen-0.1-1_0.1.8-2build2_amd64.deb ...
# Unpacking libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Selecting previously unselected package libpagemaker-0.0-0:amd64.
# Preparing to unpack .../117-libpagemaker-0.0-0_0.0.4-1build3_amd64.deb ...
# Unpacking libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../118-lp-solve_5.5.2.5-2build2_amd64.deb ...
# Unpacking lp-solve (5.5.2.5-2build2) ...
# Selecting previously unselected package libwps-0.4-4:amd64.
# Preparing to unpack .../119-libwps-0.4-4_0.4.12-2build1_amd64.deb ...
# Unpacking libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Selecting previously unselected package libreoffice-calc.
# Preparing to unpack .../120-libreoffice-calc_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-calc (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../121-libvisio-0.1-1_0.1.7-1build5_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../122-libwpd-0.10-10_0.10.3-2build1_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../123-libwpg-0.3-3_0.3.3-1build3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Selecting previously unselected package libreoffice-draw.
# Preparing to unpack .../124-libreoffice-draw_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-draw (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-impress.
# Preparing to unpack .../125-libreoffice-impress_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-impress (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-math.
# Preparing to unpack .../126-libreoffice-math_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-math (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-report-builder-bin.
# Preparing to unpack .../127-libreoffice-report-builder-bin_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-writer.
# Preparing to unpack .../128-libreoffice-writer_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-writer (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package python3-uno.
# Preparing to unpack .../129-python3-uno_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking python3-uno (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice.
# Preparing to unpack .../130-libreoffice_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-gnome.
# Preparing to unpack .../131-libreoffice-gnome_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-gtk3.
# Preparing to unpack .../132-libreoffice-gtk3_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-java-common.
# Preparing to unpack .../133-libreoffice-java-common_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-report-builder.
# Preparing to unpack .../134-libreoffice-report-builder_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-bsh.
# Preparing to unpack .../135-libreoffice-script-provider-bsh_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-js.
# Preparing to unpack .../136-libreoffice-script-provider-js_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-script-provider-python.
# Preparing to unpack .../137-libreoffice-script-provider-python_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-firebird.
# Preparing to unpack .../138-libreoffice-sdbc-firebird_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-hsqldb.
# Preparing to unpack .../139-libreoffice-sdbc-hsqldb_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-mysql.
# Preparing to unpack .../140-libreoffice-sdbc-mysql_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-sdbc-postgresql.
# Preparing to unpack .../141-libreoffice-sdbc-postgresql_1%3a7.3.7-0ubuntu0.22.04.10_amd64.deb ...
# Unpacking libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-style-elementary.
# Preparing to unpack .../142-libreoffice-style-elementary_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-style-yaru.
# Preparing to unpack .../143-libreoffice-style-yaru_1%3a7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package libreoffice-wiki-publisher.
# Preparing to unpack .../144-libreoffice-wiki-publisher_1.2.0+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.10) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../145-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libreoffice-nlpsolver.
# Preparing to unpack .../146-libreoffice-nlpsolver_0.9+LibO7.3.7-0ubuntu0.22.04.10_all.deb ...
# Unpacking libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up fonts-sil-gentium-basic (1.102-1.1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libtommath1:amd64 (1.2.0-6ubuntu0.22.04.1) ...
# Setting up libboost-iostreams1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up fonts-noto-extra (20201225-1build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/rmid to provide /usr/bin/rmid (rmid) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/pack200 to provide /usr/bin/pack200 (pack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/unpack200 to provide /usr/bin/unpack200 (unpack200) in auto mode
# Setting up libyajl2:amd64 (2.1.0-3ubuntu0.22.04.1) ...
# Setting up libuno-sal3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libel-api-java (3.0.0-3) ...
# Setting up libboost-filesystem1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up openjdk-11-jre:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Setting up libeot0:amd64 (0.01-5build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libgpgme11:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up firebird3.0-common-doc (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu7) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Setting up firebird3.0-common (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up apparmor (3.0.4-2ubuntu2.5) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up fonts-sil-gentium (20081126:1.03-4) ...
# Setting up libreoffice-style-colibre (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up liborcus-parser-0.17-0:amd64 (0.17.2-2) ...
# Setting up fonts-liberation2 (2.1.5-1) ...
# Setting up libwebsocket-api-java (1.1-2) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libfreehand-0.1-1 (0.1.2-3build2) ...
# Setting up libclucene-core1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2ubuntu0.3) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up fonts-linuxlibertine (5.3.0-6) ...
# Setting up libbsh-java (2.0b4-20) ...
# Setting up libjsp-api-java (2.3.4-3) ...
# Setting up libmhash2:amd64 (0.9.9.9-9build2) ...
# Setting up libmythes-1.2-0:amd64 (2:1.2.4-4build1) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libexttextcat-data (3.4.5-1build2) ...
# Setting up libabw-0.1-1:amd64 (0.1.3-1build3) ...
# Setting up libservlet-api-java (4.0.1-2) ...
# Setting up libepubgen-0.1-1:amd64 (0.1.1-1ubuntu5) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libuno-salhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up fonts-crosextra-caladea (20130214-2.1) ...
# Setting up libreoffice-style-yaru (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up liblangtag-common (0.6.3-2ubuntu1) ...
# Setting up libib-util:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libunoloader-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up fonts-noto-ui-core (20201225-1build1) ...
# Setting up libxmlsec1:amd64 (1.2.33-1build2) ...
# Setting up libwpd-0.10-10:amd64 (0.10.3-2build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up fonts-noto-core (20201225-1build1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up fonts-opensymbol (2:102.12+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libservlet3.1-java (1:4.0.1-2) ...
# Setting up libodfgen-0.1-1:amd64 (0.1.8-2build2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.7-1build5) ...
# Setting up libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libreoffice-style-elementary (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up fonts-dejavu (2.37-2build1) ...
# Setting up libwps-0.4-4:amd64 (0.4.12-2build1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libexttextcat-2.0-0:amd64 (3.4.5-1build2) ...
# Setting up libgpgmepp6:amd64 (1.16.0-1.2ubuntu4.2) ...
# Setting up libmspub-0.1-1:amd64 (0.1.4-3build3) ...
# Setting up libraptor2-0:amd64 (2.0.15-0ubuntu4.1) ...
# Setting up lp-solve (5.5.2.5-2build2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up libpagemaker-0.0-0:amd64 (0.0.4-1build3) ...
# Setting up libmwaw-0.3-3:amd64 (0.3.21-1build1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libcdr-0.1-1:amd64 (0.1.6-2build2) ...
# Setting up liblangtag1:amd64 (0.6.3-2ubuntu1) ...
# Setting up libfbclient2:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up liborcus-0.17-0:amd64 (0.17.2-2) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up firebird3.0-utils (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up libuno-cppu3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libhsqldb1.8.0-java (1.8.0.10+dfsg-11) ...
# Setting up libclucene-contribs1v5:amd64 (2.3.3.4+dfsg-1ubuntu5) ...
# Setting up libwpg-0.3-3:amd64 (0.3.3-1build3) ...
# Setting up libxmlsec1-nss:amd64 (1.2.33-1build2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libboost-locale1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up gstreamer1.0-gl:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up libuno-purpenvhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up uno-libs-private (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up firebird3.0-server-core:amd64 (3.0.8.33535.ds4-1ubuntu2) ...
# Setting up librasqal3:amd64 (0.9.33-0.2ubuntu1) ...
# Setting up libetonyek-0.1-1:amd64 (0.1.10-3build1) ...
# Setting up libe-book-0.1-1:amd64 (0.1.3-2build2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up librdf0:amd64 (1.0.17-1.1ubuntu3) ...
# Setting up libuno-cppuhelpergcc3-3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up ure (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-common (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/main.xcd with new version
#
# Creating config file /etc/libreoffice/registry/pdfimport.xcd with new version
#
# Creating config file /etc/libreoffice/registry/xsltfilter.xcd with new version
#
# Creating config file /etc/libreoffice/registry/lingucomponent.xcd with new version
#
# Creating config file /etc/libreoffice/registry/Langpack-en-US.xcd with new version
#
# Creating config file /etc/libreoffice/registry/res/fcfg_langpack_en-US.xcd with new version
# Setting up ure-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-math (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/math.xcd with new version
# Setting up libreoffice-sdbc-postgresql (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/postgresql.xcd with new version
# Setting up liblibreoffice-java (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-draw (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/draw.xcd with new version
#
# Creating config file /etc/libreoffice/registry/graphicfilter.xcd with new version
# Setting up libreoffice-java-common (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-base-drivers (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-wiki-publisher (1.2.0+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-sdbc-firebird (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-sdbc-mysql (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-gnome (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/gnome.xcd with new version
# Setting up libreoffice-impress (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/impress.xcd with new version
#
# Creating config file /etc/libreoffice/registry/ogltrans.xcd with new version
# Setting up libreoffice-base-core (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up python3-uno (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/pyuno.xcd with new version
# Setting up libreoffice-script-provider-bsh (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-script-provider-js (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-calc (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/calc.xcd with new version
# Setting up libreoffice-base (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/base.xcd with new version
# Setting up libreoffice-sdbc-hsqldb (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-writer (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/writer.xcd with new version
# Setting up libreoffice-script-provider-python (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-nlpsolver (0.9+LibO7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-report-builder-bin (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice (1:7.3.7-0ubuntu0.22.04.10) ...
# Setting up libreoffice-report-builder (1:7.3.7-0ubuntu0.22.04.10) ...
#
# Creating config file /etc/libreoffice/registry/reportbuilder.xcd with new version
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Setting up libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Setting up gstreamer1.0-gtk3:amd64 (1.20.3-0ubuntu1.5) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Setting up libreoffice-gtk3 (1:7.3.7-0ubuntu0.22.04.10) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# LibreOffice 7.3.7.2 30(Build:2)

# %%
import pandas as pd
import numpy as np
import fitz ## PyMuPDF
import re
import hashlib
import json
import time
import subprocess
import matplotlib.pyplot as plt
import zipfile

from pathlib import Path
from docx import Document
from google.colab import drive
from IPython.display import display, HTML
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
## find zip
zip_files = list(Path("/content").glob("*.zip"))

if len(zip_files) == 0:
    raise ValueError("No ZIP file found. Please upload one.")

zip_path = zip_files[0]
print(f"Using: {zip_path.name}")

## extract
extract_path = Path("/content/input_data")
extract_path.mkdir(exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

DATA_PATH = extract_path

print("\n Done!")
print("DATA_PATH =", DATA_PATH)

print("\nPreview:")
for f in DATA_PATH.rglob("*"):
    print("-", f)
# Out:
# Using: _final docs.zip
#
#  Done!
# DATA_PATH = /content/input_data
#
# Preview:
# - /content/input_data/_final docs
# - /content/input_data/__MACOSX
# - /content/input_data/_final docs/8. Faculty & Researcher National & International Service 2025 final.docx
# - /content/input_data/_final docs/archives
# - /content/input_data/_final docs/9. Post Doc 2025 final.pdf
# - /content/input_data/_final docs/.DS_Store
# - /content/input_data/_final docs/3. Faculty and Researcher Grant Funding 2025 final.pdf
# - /content/input_data/_final docs/7. Faculty & Researcher Local & State Service 2025 final.pdf
# - /content/input_data/_final docs/7. Faculty & Researcher Local & State Service 2025 final.docx
# - /content/input_data/_final docs/4. Faculty & Researcher Scholarly Work 2025 final.pdf
# - /content/input_data/_final docs/10. Grad Students 2025 final.pdf
# - /content/input_data/_final docs/3. Faculty and Researcher Grant Funding 2025 final.docx
# - /content/input_data/_final docs/5. Faculty & Researcher Presentations & Meeting Participation 2025 final.docx
# - /content/input_data/_final docs/4. Faculty & Researcher Scholarly Work 2025 final.docx
# - /content/input_data/_final docs/1. External Faculty 2025 final.docx
# - /content/input_data/_final docs/6. Faculty and Researcher Awards & Recognition 2025 final.pdf
# - /content/input_data/_final docs/6. Faculty and Researcher Awards & Recognition 2025 final.docx
# - /content/input_data/_final docs/10. Grad Students 2025 final.docx
# - /content/input_data/_final docs/5. Faculty & Researcher Presentations & Meeting Participation 2025 final.pdf
# - /content/input_data/_final docs/1. External Faculty 2025 final.pdf
# - /content/input_data/_final docs/8. Faculty & Researcher National & International Service 2025 final.pdf
# - /content/input_data/_final docs/9. Post Doc 2025 final.docx
# - /content/input_data/__MACOSX/_final docs
# - /content/input_data/__MACOSX/.__final docs
# - /content/input_data/_final docs/archives/3. Faculty and Researcher Grant Funding 2025 8-1-25 rd.docx
# - /content/input_data/_final docs/archives/8. Faculty & Researcher National & International Service 2025 8-1-25 rd.docx
# - /content/input_data/_final docs/archives/10. Grad Students 2025 6-21-25 rd.docx
# - /content/input_data/_final docs/archives/1. External Faculty 2025 6-12-25 rd.docx
# - /content/input_data/_final docs/archives/5. Faculty & Researcher Presentations & Meeting Participation 2025 8-1-25 rd copy.docx
# - /content/input_data/_final docs/archives/4. Faculty & Researcher Scholarly Work 2025 8-1-25 rd.docx
# - /content/input_data/_final docs/archives/7. Faculty & Researcher Local & State Service 2025 8-1-25 rd.docx
# - /content/input_data/_final docs/archives/6. Faculty and Researcher Awards & Recognition 2025 8-1-25 rd.docx
# - /content/input_data/_final docs/archives/9. Post Doc 2025 06-15-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives
# - /content/input_data/__MACOSX/_final docs/._1. External Faculty 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._8. Faculty & Researcher National & International Service 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._9. Post Doc 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._7. Faculty & Researcher Local & State Service 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._6. Faculty and Researcher Awards & Recognition 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._7. Faculty & Researcher Local & State Service 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._10. Grad Students 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._3. Faculty and Researcher Grant Funding 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._.DS_Store
# - /content/input_data/__MACOSX/_final docs/._5. Faculty & Researcher Presentations & Meeting Participation 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._1. External Faculty 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._6. Faculty and Researcher Awards & Recognition 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._9. Post Doc 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._4. Faculty & Researcher Scholarly Work 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._8. Faculty & Researcher National & International Service 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._3. Faculty and Researcher Grant Funding 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._4. Faculty & Researcher Scholarly Work 2025 final.docx
# - /content/input_data/__MACOSX/_final docs/._archives
# - /content/input_data/__MACOSX/_final docs/._5. Faculty & Researcher Presentations & Meeting Participation 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/._10. Grad Students 2025 final.pdf
# - /content/input_data/__MACOSX/_final docs/archives/._4. Faculty & Researcher Scholarly Work 2025 8-1-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._6. Faculty and Researcher Awards & Recognition 2025 8-1-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._9. Post Doc 2025 06-15-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._5. Faculty & Researcher Presentations & Meeting Participation 2025 8-1-25 rd copy.docx
# - /content/input_data/__MACOSX/_final docs/archives/._3. Faculty and Researcher Grant Funding 2025 8-1-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._8. Faculty & Researcher National & International Service 2025 8-1-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._1. External Faculty 2025 6-12-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._7. Faculty & Researcher Local & State Service 2025 8-1-25 rd.docx
# - /content/input_data/__MACOSX/_final docs/archives/._10. Grad Students 2025 6-21-25 rd.docx

# %%
BASE = DATA_PATH

# %%
## non-nested target file aggregation
rows = []

## constants
TARGET_KEYWORDS = ["final", "lb"]
TARGET_EXTENSIONS = [".pdf", ".docx"]

## input folder
input_folder = BASE  ## or whatever your uploaded folder path is

## missing input folder check
if not input_folder.exists():
    raise ValueError(f"Input folder does not exist: {input_folder}")

## find target files directly inside input folder only
all_files = [
    f for f in input_folder.rglob("*")
    if f.is_file()
    and "__MACOSX" not in f.parts
    and not f.name.startswith("._")
    and f.name != ".DS_Store"
]

## find target files
target_files = []

for f in all_files:
    name_lower = f.name.lower()
    ext = f.suffix.lower()

    if ext in TARGET_EXTENSIONS and any(keyword in name_lower for keyword in TARGET_KEYWORDS):
        target_files.append(f)

## record results
if not target_files:
    rows.append({
        "status": "no_target_files_found",
        "file_path": None,
        "ext": None
    })
else:
    for f in target_files:
        rows.append({
            "status": "target_file_found",
            "file_path": str(f),
            "file_name": f.name,
            "ext": f.suffix.lower()
        })

df_target_files = pd.DataFrame(rows)

print("input folder:", input_folder)
print("target files found:", len(target_files))
# Out:
# input folder: /content/input_data
# target files found: 18

# %%
## clean filename down to a shared core title
def make_core_title(name: str) -> str:
    if not isinstance(name, str):
        return ""

    s = Path(name).stem.lower().strip()

    ## remove leading punctuation (., -, _) before anything
    s = re.sub(r"^[\s\.\-_]+", "", s)

    ## remove leading numbering like "1. ", "10. ", "1 - ", "1 "
    s = re.sub(r"^\d+\.\s*", "", s)
    s = re.sub(r"^\d+\s*-\s*", "", s)
    s = re.sub(r"^\d+\s+", "", s)

    ## normalize symbols
    s = s.replace("&", "and")

    ## remove common tags
    s = re.sub(r"\bfinal\b", "", s)
    s = re.sub(r"\blb\b", "", s)

    ## remove dates like 5-30-25, 05-30-2025, etc.
    s = re.sub(r"\b\d{1,2}-\d{1,2}-\d{2,4}\b", "", s)

    ## normalize separators
    s = re.sub(r"[_\-]+", " ", s)

    ## collapse whitespace
    s = re.sub(r"\s+", " ", s).strip()

    return s


## build dataframe
df_target_files = pd.DataFrame(rows)

## keep only valid target files
df_target_files = df_target_files[
    df_target_files["status"] == "target_file_found"
].copy()

## extract filename
df_target_files["file_name"] = df_target_files["file_path"].apply(
    lambda x: Path(x).name if pd.notna(x) else None
)

## create normalized core title
df_target_files["core_title"] = df_target_files["file_name"].apply(make_core_title)

## extension preference (lower is better)
ext_priority = {
    ".pdf": 1,
    ".docx": 2,
    ".doc": 3
}

df_target_files["ext_rank"] = df_target_files["ext"].map(ext_priority).fillna(99)

## sort so best file (pdf) comes first within each group
df_target_files = df_target_files.sort_values(
    ["core_title", "ext_rank", "file_name"]
).copy()

## deduplicate based on normalized title
df_target_files_dedup = df_target_files.drop_duplicates(
    subset=["core_title"],
    keep="first"
).copy()

## summary stats
print("before dedup:", len(df_target_files))
print("after dedup:", len(df_target_files_dedup))
print("removed:", len(df_target_files) - len(df_target_files_dedup))

## optional: inspect duplicates that were removed
dupes = df_target_files[df_target_files.duplicated("core_title", keep=False)]
print("\nDuplicate groups preview:")
display(dupes[["file_name", "core_title", "ext"]].sort_values("core_title"))

## final output
df_target_files_dedup.head()
# Out:
# before dedup: 18
# after dedup: 9
# removed: 9
#
# Duplicate groups preview:
#                                             file_name  \
# 15                 1. External Faculty 2025 final.pdf
# 10                1. External Faculty 2025 final.docx
# 11  6. Faculty and Researcher Awards & Recognition...
# 12  6. Faculty and Researcher Awards & Recognition...
# 2   3. Faculty and Researcher Grant Funding 2025 f...
# 7   3. Faculty and Researcher Grant Funding 2025 f...
# 3   7. Faculty & Researcher Local & State Service ...
# 4   7. Faculty & Researcher Local & State Service ...
# 0   8. Faculty & Researcher National & Internation...
# 16  8. Faculty & Researcher National & Internation...
# 14  5. Faculty & Researcher Presentations & Meetin...
# 8   5. Faculty & Researcher Presentations & Meetin...
# 5   4. Faculty & Researcher Scholarly Work 2025 fi...
# 9   4. Faculty & Researcher Scholarly Work 2025 fi...
# 6                    10. Grad Students 2025 final.pdf
# 13                  10. Grad Students 2025 final.docx
# 1                          9. Post Doc 2025 final.pdf
# 17                        9. Post Doc 2025 final.docx
#
#                                            core_title    ext
# 15                              external faculty 2025   .pdf
# 10                              external faculty 2025  .docx
# 11  faculty and researcher awards and recognition ...   .pdf
# 12  faculty and researcher awards and recognition ...  .docx
# 2           faculty and researcher grant funding 2025   .pdf
# 7           faculty and researcher grant funding 2025  .docx
# 3   faculty and researcher local and state service...   .pdf
# 4   faculty and researcher local and state service...  .docx
# 0   faculty and researcher national and internatio...  .docx
# 16  faculty and researcher national and internatio...   .pdf
# 14  faculty and researcher presentations and meeti...   .pdf
# 8   faculty and researcher presentations and meeti...  .docx
# 5          faculty and researcher scholarly work 2025   .pdf
# 9          faculty and researcher scholarly work 2025  .docx
# 6                                  grad students 2025   .pdf
# 13                                 grad students 2025  .docx
# 1                                       post doc 2025   .pdf
# 17                                      post doc 2025  .docx
#                status                                          file_path  \
# 15  target_file_found  /content/input_data/_final docs/1. External Fa...
# 11  target_file_found  /content/input_data/_final docs/6. Faculty and...
# 2   target_file_found  /content/input_data/_final docs/3. Faculty and...
# 3   target_file_found  /content/input_data/_final docs/7. Faculty & R...
# 16  target_file_found  /content/input_data/_final docs/8. Faculty & R...
#
#                                             file_name   ext  \
# 15                 1. External Faculty 2025 final.pdf  .pdf
# 11  6. Faculty and Researcher Awards & Recognition...  .pdf
# 2   3. Faculty and Researcher Grant Funding 2025 f...  .pdf
# 3   7. Faculty & Researcher Local & State Service ...  .pdf
# 16  8. Faculty & Researcher National & Internation...  .pdf
#
#                                            core_title  ext_rank
# 15                              external faculty 2025         1
# 11  faculty and researcher awards and recognition ...         1
# 2           faculty and researcher grant funding 2025         1
# 3   faculty and researcher local and state service...         1
# 16  faculty and researcher national and internatio...         1

# %%
## table of leftover files with paths
leftover_table = (
    df_target_files_dedup[["file_name", "ext"]]
    .sort_values(["file_name"])
    .reset_index(drop=True)
)

leftover_table
# Out:
#                                            file_name   ext
# 0                 1. External Faculty 2025 final.pdf  .pdf
# 1                   10. Grad Students 2025 final.pdf  .pdf
# 2  3. Faculty and Researcher Grant Funding 2025 f...  .pdf
# 3  4. Faculty & Researcher Scholarly Work 2025 fi...  .pdf
# 4  5. Faculty & Researcher Presentations & Meetin...  .pdf
# 5  6. Faculty and Researcher Awards & Recognition...  .pdf
# 6  7. Faculty & Researcher Local & State Service ...  .pdf
# 7  8. Faculty & Researcher National & Internation...  .pdf
# 8                         9. Post Doc 2025 final.pdf  .pdf

# %%
## folder to store converted .doc files
BASE_CONVERTED = Path("/content/converted_docx")
BASE_CONVERTED.mkdir(parents=True, exist_ok=True)


## conversion function
def convert_doc_to_docx(src_doc: Path, dst_docx: Path) -> tuple[bool, str]:
    try:
        dst_docx.parent.mkdir(parents=True, exist_ok=True)

        ## skip if converted file already exists and is current
        if dst_docx.exists() and dst_docx.stat().st_mtime >= src_doc.stat().st_mtime:
            return True, "skipped_up_to_date"

        cmd = [
            "soffice", "--headless", "--nologo", "--nofirststartwizard",
            "--convert-to", "docx",
            "--outdir", str(dst_docx.parent),
            str(src_doc),
        ]

        r = subprocess.run(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )

        expected = dst_docx.parent / (src_doc.stem + ".docx")

        if r.returncode != 0:
            return False, f"convert_error: {r.stderr.strip()[:300]}"

        if not expected.exists():
            return False, "convert_error: output_missing"

        if expected.resolve() != dst_docx.resolve():
            expected.replace(dst_docx)

        return True, "converted"

    except Exception as e:
        return False, f"convert_error: {str(e)}"


## isolate leftover .doc files from deduplicated target files
leftover_doc_df = df_target_files_dedup[
    df_target_files_dedup["ext"] == ".doc"
].copy()


## initialize counters
converted = 0
skipped = 0
failed = 0
fail_samples = []


## process only leftover .doc files
for _, row in leftover_doc_df.iterrows():

    src_doc = Path(row["file_path"])

    if not src_doc.exists():
        failed += 1
        if len(fail_samples) < 5:
            fail_samples.append((str(src_doc), "file_missing"))
        continue

    ## save converted file using same filename, but .docx extension
    dst_docx = BASE_CONVERTED / src_doc.with_suffix(".docx").name

    ok, msg = convert_doc_to_docx(src_doc, dst_docx)

    if ok and msg == "converted":
        converted += 1
    elif ok and msg == "skipped_up_to_date":
        skipped += 1
    else:
        failed += 1
        if len(fail_samples) < 5:
            fail_samples.append((str(src_doc), msg))


## print summary
print(f"DOC → DOCX conversion: converted={converted}, skipped_up_to_date={skipped}, failed={failed}")

if fail_samples:
    print("Sample failures:")
    for p, m in fail_samples:
        print(" ", p, "=>", m)
# Out:
# DOC → DOCX conversion: converted=0, skipped_up_to_date=0, failed=0

# %%
ALLOWED_EXTS = {".pdf", ".docx"}

## extract text from pdf using PyMuPDF
def extract_text_pdf(path: Path, block_gap_threshold=14):
    try:
        output_pages = []

        with fitz.open(path) as doc:
            for page in doc:
                text_dict = page.get_text("dict")
                extracted_lines = []

                ## collect text lines from text blocks only
                for block in text_dict["blocks"]:
                    if block["type"] != 0:
                        continue

                    for line in block["lines"]:
                        spans = line["spans"]
                        line_text = "".join(span["text"] for span in spans).strip()

                        if not line_text:
                            continue

                        x0 = min(span["bbox"][0] for span in spans)
                        y0 = min(span["bbox"][1] for span in spans)
                        x1 = max(span["bbox"][2] for span in spans)
                        y1 = max(span["bbox"][3] for span in spans)

                        extracted_lines.append({
                            "text": line_text,
                            "x0": x0,
                            "y0": y0,
                            "x1": x1,
                            "y1": y1,
                        })

                ## sort lines in reading order
                extracted_lines.sort(key=lambda ln: (round(ln["y0"], 1), ln["x0"]))

                if not extracted_lines:
                    output_pages.append("")
                    continue

                page_parts = [extracted_lines[0]["text"]]
                prev_line = extracted_lines[0]

                for line in extracted_lines[1:]:
                    vertical_gap = line["y0"] - prev_line["y1"]

                    if vertical_gap > block_gap_threshold:
                        page_parts.append("\n\n")
                    else:
                        page_parts.append("\n")

                    page_parts.append(line["text"])
                    prev_line = line

                output_pages.append("".join(page_parts).strip())

        return True, "\n\n".join(output_pages).strip(), None

    except Exception as e:
        return False, None, f"pdf_error: {str(e)}"


## extract text from docx using python-docx
def extract_text_docx(path: Path):
    try:
        doc = Document(path)
        text = "\n".join(p.text for p in doc.paragraphs)
        return True, text, None
    except Exception as e:
        return False, None, f"docx_error: {str(e)}"


## route file based on file extension
def extract_text_any(path: Path):
    ext = path.suffix.lower()

    if ext == ".pdf":
        return extract_text_pdf(path)

    if ext == ".docx":
        return extract_text_docx(path)

    return False, None, f"unsupported_ext: {ext}"


## preserve line breaks for downstream section/citation detection
def normalize_text_for_txt(text: str) -> str:
    if not text:
        return ""

    text = text.replace("\r\n", "\n").replace("\r", "\n")
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n{3,}", "\n\n", text)

    return text.strip()


## if any .doc files were converted, point to converted .docx
def resolve_preferred_path(path_str: str) -> str:
    src = Path(path_str)

    if src.suffix.lower() == ".doc":
        converted = BASE_CONVERTED / src.with_suffix(".docx").name

        if converted.exists():
            return str(converted)

    return str(src)


## initialize extraction rows
corpus_rows = []
seen_doc_ids = set()


## extract from deduplicated target file table
def extract_from_target_table(df_files: pd.DataFrame):
    """
    df_files: deduplicated target file table
              should contain file_path, ext, file_name, and core_title
    """

    for _, row in df_files.iterrows():
        f = Path(row["file_path"])

        if not f.exists():
            corpus_rows.append({
                "doc_id": str(row["file_path"]),
                "core_title": row.get("core_title", None),
                "file_name": row.get("file_name", None),
                "path": str(row["file_path"]),
                "ext": row.get("ext", None),
                "ok": False,
                "fail_reason": "file_missing",
                "n_chars": 0,
                "n_words": 0,
                "text": None
            })
            continue

        ext = f.suffix.lower()

        if ext not in ALLOWED_EXTS:
            corpus_rows.append({
                "doc_id": str(f),
                "core_title": row.get("core_title", None),
                "file_name": f.name,
                "path": str(f),
                "ext": ext,
                "ok": False,
                "fail_reason": f"unsupported_ext: {ext}",
                "n_chars": 0,
                "n_words": 0,
                "text": None
            })
            continue

        ## use filename/core title as document identifier for this single-folder workflow
        doc_id = row.get("core_title", f.stem)

        if doc_id in seen_doc_ids:
            continue

        seen_doc_ids.add(doc_id)

        ok, text, reason = extract_text_any(f)

        if ok and text:
            text = normalize_text_for_txt(text)

        corpus_rows.append({
            "doc_id": doc_id,
            "core_title": row.get("core_title", None),
            "file_name": f.name,
            "path": str(f),
            "ext": ext,
            "ok": ok,
            "fail_reason": reason,
            "n_chars": len(text) if text else 0,
            "n_words": len(re.findall(r"\S+", text)) if text else 0,
            "text": text if ok else None
        })


## use deduplicated target files
extract_input_df = df_target_files_dedup.copy()

## resolve converted .doc files if applicable
extract_input_df["file_path"] = extract_input_df["file_path"].apply(resolve_preferred_path)
extract_input_df["ext"] = extract_input_df["file_path"].apply(lambda x: Path(x).suffix.lower())
extract_input_df["file_name"] = extract_input_df["file_path"].apply(lambda x: Path(x).name)

## extract text
extract_from_target_table(extract_input_df)

## final corpus table
df_target_corpus = pd.DataFrame(corpus_rows)

print("total documents:", len(df_target_corpus))
print("successful extractions:", df_target_corpus["ok"].sum())
print("failed extractions:", (~df_target_corpus["ok"]).sum())

df_target_corpus.head()
# Out:
# total documents: 9
# successful extractions: 9
# failed extractions: 0
#                                               doc_id  \
# 0                              external faculty 2025
# 1  faculty and researcher awards and recognition ...
# 2          faculty and researcher grant funding 2025
# 3  faculty and researcher local and state service...
# 4  faculty and researcher national and internatio...
#
#                                           core_title  \
# 0                              external faculty 2025
# 1  faculty and researcher awards and recognition ...
# 2          faculty and researcher grant funding 2025
# 3  faculty and researcher local and state service...
# 4  faculty and researcher national and internatio...
#
#                                            file_name  \
# 0                 1. External Faculty 2025 final.pdf
# 1  6. Faculty and Researcher Awards & Recognition...
# 2  3. Faculty and Researcher Grant Funding 2025 f...
# 3  7. Faculty & Researcher Local & State Service ...
# 4  8. Faculty & Researcher National & Internation...
#
#                                                 path   ext    ok fail_reason  \
# 0  /content/input_data/_final docs/1. External Fa...  .pdf  True        None
# 1  /content/input_data/_final docs/6. Faculty and...  .pdf  True        None
# 2  /content/input_data/_final docs/3. Faculty and...  .pdf  True        None
# 3  /content/input_data/_final docs/7. Faculty & R...  .pdf  True        None
# 4  /content/input_data/_final docs/8. Faculty & R...  .pdf  True        None
#
#    n_chars  n_words                                               text
# 0    24702     3382  Johari Harris\n\nHONORS & AWARDS\n2025 Outstan...
# 1     5821      796  Nancy Deutsch\n\nHONORS\n• Organizational Awar...
# 2    35485     4954  Nancy Deutsch\n\nGRANTS AND SPONSORED PROJECTS...
# 3    13398     1857  Nancy Deutsch\n\nUNIVERSITY SERVICE\n• ITHRIVE...
# 4    18414     2524  Nancy Deutsch\n\nNATIONAL ADVISORY BOARDS AND ...

# %%
## filter successful extractions
df_ok = df_target_corpus[df_target_corpus["ok"] == True].copy()

## define txt output folder (local Colab)
TXT_ROOT = Path("/content/youthnex_txt_spaces")
TXT_ROOT.mkdir(parents=True, exist_ok=True)


## safe filename function (prevents weird characters breaking files)
def safe_filename(name: str) -> str:
    name = str(name).lower().strip()
    name = re.sub(r"[^\w\s-]", "", name)   ## remove special chars
    name = re.sub(r"\s+", "_", name)       ## spaces → underscores
    return name[:120]                     ## avoid super long names


## write one .txt per document
saved = 0

for _, row in df_ok.iterrows():
    text = row["text"]
    if not text:
        continue

    ## choose best name (core_title preferred)
    base_name = row.get("core_title") or row.get("doc_id") or row.get("file_name")

    fname = safe_filename(base_name)
    txt_path = TXT_ROOT / f"{fname}.txt"

    txt_path.write_text(text, encoding="utf-8")
    saved += 1


## summary
print("txt files saved:", saved)
print("saved to:", TXT_ROOT)
# Out:
# txt files saved: 9
# saved to: /content/youthnex_txt_spaces

# %% [markdown]
# ## Bibliographic Extraction

# %%
## local Colab folder containing extracted .txt files
TXT_ROOT = Path("/content/youthnex_txt_spaces")
EXPORT_PREFIX = "biblio_stabilized"


def load_txt_corpus(txt_root: Path) -> pd.DataFrame:
    txt_root = Path(txt_root)

    if not txt_root.exists():
        raise FileNotFoundError(
            f"TXT_ROOT does not exist: {txt_root.resolve()}\n"
            "Point TXT_ROOT to the folder containing the preprocessed .txt files."
        )

    rows = []

    for txt_file in sorted(txt_root.rglob("*.txt")):
        rel = txt_file.relative_to(txt_root)
        text = txt_file.read_text(encoding="utf-8", errors="ignore")

        rows.append({
            "doc_id": txt_file.stem,
            "doc_uid": str(rel.with_suffix("")),
            "path": str(txt_file),
            "text": text,
        })

    df = pd.DataFrame(rows)

    if df.empty:
        raise ValueError(f"No .txt files found under: {txt_root.resolve()}")

    return df


df_corpus = load_txt_corpus(TXT_ROOT)

print("Rows loaded:", len(df_corpus))
print("Unique doc_uid:", df_corpus["doc_uid"].nunique())
print("Unique doc_id:", df_corpus["doc_id"].nunique())

df_corpus.head()
# Out:
# Rows loaded: 9
# Unique doc_uid: 9
# Unique doc_id: 9
#                                               doc_id  \
# 0                              external_faculty_2025
# 1  faculty_and_researcher_awards_and_recognition_...
# 2          faculty_and_researcher_grant_funding_2025
# 3  faculty_and_researcher_local_and_state_service...
# 4  faculty_and_researcher_national_and_internatio...
#
#                                              doc_uid  \
# 0                              external_faculty_2025
# 1  faculty_and_researcher_awards_and_recognition_...
# 2          faculty_and_researcher_grant_funding_2025
# 3  faculty_and_researcher_local_and_state_service...
# 4  faculty_and_researcher_national_and_internatio...
#
#                                                 path  \
# 0  /content/youthnex_txt_spaces/external_faculty_...
# 1  /content/youthnex_txt_spaces/faculty_and_resea...
# 2  /content/youthnex_txt_spaces/faculty_and_resea...
# 3  /content/youthnex_txt_spaces/faculty_and_resea...
# 4  /content/youthnex_txt_spaces/faculty_and_resea...
#
#                                                 text
# 0  Johari Harris\n\nHONORS & AWARDS\n2025 Outstan...
# 1  Nancy Deutsch\n\nHONORS\n• Organizational Awar...
# 2  Nancy Deutsch\n\nGRANTS AND SPONSORED PROJECTS...
# 3  Nancy Deutsch\n\nUNIVERSITY SERVICE\n• ITHRIVE...
# 4  Nancy Deutsch\n\nNATIONAL ADVISORY BOARDS AND ...

# %%
def normalize_text_multiline(text: str) -> str:
    if not isinstance(text, str) or not text.strip():
        return ""

    text = text.replace("\r\n", "\n").replace("\r", "\n")
    lines = [ln.rstrip() for ln in text.split("\n")]

    cleaned = []
    blank_count = 0

    for ln in lines:
        if ln.strip() == "":
            blank_count += 1
            if blank_count <= 2:
                cleaned.append("")
        else:
            blank_count = 0
            cleaned.append(ln)

    return "\n".join(cleaned).strip()


def normalize_text_flat(text: str) -> str:
    if not isinstance(text, str) or not text.strip():
        return ""

    text = text.replace("\r\n", "\n").replace("\r", "\n")
    text = text.replace("\n", " ").replace("\t", " ")

    return re.sub(r"\s+", " ", text).strip()


## apply normalization
df_corpus["text_multiline"] = df_corpus["text"].fillna("").apply(normalize_text_multiline)
df_corpus["text_flat"] = df_corpus["text"].fillna("").apply(normalize_text_flat)

## quick check
print("documents normalized:", len(df_corpus))
print("empty multiline texts:", (df_corpus["text_multiline"] == "").sum())
print("empty flat texts:", (df_corpus["text_flat"] == "").sum())

df_corpus[["doc_uid", "path", "text_multiline", "text_flat"]].head()
# Out:
# documents normalized: 9
# empty multiline texts: 0
# empty flat texts: 0
#                                              doc_uid  \
# 0                              external_faculty_2025
# 1  faculty_and_researcher_awards_and_recognition_...
# 2          faculty_and_researcher_grant_funding_2025
# 3  faculty_and_researcher_local_and_state_service...
# 4  faculty_and_researcher_national_and_internatio...
#
#                                                 path  \
# 0  /content/youthnex_txt_spaces/external_faculty_...
# 1  /content/youthnex_txt_spaces/faculty_and_resea...
# 2  /content/youthnex_txt_spaces/faculty_and_resea...
# 3  /content/youthnex_txt_spaces/faculty_and_resea...
# 4  /content/youthnex_txt_spaces/faculty_and_resea...
#
#                                       text_multiline  \
# 0  Johari Harris\n\nHONORS & AWARDS\n2025 Outstan...
# 1  Nancy Deutsch\n\nHONORS\n• Organizational Awar...
# 2  Nancy Deutsch\n\nGRANTS AND SPONSORED PROJECTS...
# 3  Nancy Deutsch\n\nUNIVERSITY SERVICE\n• ITHRIVE...
# 4  Nancy Deutsch\n\nNATIONAL ADVISORY BOARDS AND ...
#
#                                            text_flat
# 0  Johari Harris HONORS & AWARDS 2025 Outstanding...
# 1  Nancy Deutsch HONORS • Organizational Award fo...
# 2  Nancy Deutsch GRANTS AND SPONSORED PROJECTS - ...
# 3  Nancy Deutsch UNIVERSITY SERVICE • ITHRIVE Men...
# 4  Nancy Deutsch NATIONAL ADVISORY BOARDS AND WOR...

# %%
## expanded publication keyword detection
PUB_ANYWHERE_RE = re.compile(
    r"publicat|bibliograph|journal|article|peer[- ]reviewed|refereed|book chapter|scholarly work|papers?",
    flags=re.IGNORECASE
)

diag_rows = []

for _, row in df_corpus.iterrows():
    text = row["text_multiline"]

    m = PUB_ANYWHERE_RE.search(text)

    diag_rows.append({
        "doc_uid": row["doc_uid"],
        "has_pub_keyword_anywhere": bool(m),

        ## structural diagnostics
        "n_lines": len(text.split("\n")) if isinstance(text, str) and text else 0,
        "n_blank_lines": sum(
            1 for ln in text.split("\n") if not ln.strip()
        ) if isinstance(text, str) and text else 0,
    })

df_diag = pd.DataFrame(diag_rows)

## summary stats
print("Documents with publication-like keyword anywhere:",
      int(df_diag["has_pub_keyword_anywhere"].sum()))

print("Percent with publication content:",
      round(100 * df_diag["has_pub_keyword_anywhere"].mean(), 1), "%")

print("Median lines per doc:",
      int(df_diag["n_lines"].median()))

print("Median blank lines per doc:",
      int(df_diag["n_blank_lines"].median()))

## optional: flag likely non-publication docs
df_diag["likely_non_pub_doc"] = ~df_diag["has_pub_keyword_anywhere"]

df_diag
# Out:
# Documents with publication-like keyword anywhere: 7
# Percent with publication content: 77.8 %
# Median lines per doc: 491
# Median blank lines per doc: 69
#                                              doc_uid  \
# 0                              external_faculty_2025
# 1  faculty_and_researcher_awards_and_recognition_...
# 2          faculty_and_researcher_grant_funding_2025
# 3  faculty_and_researcher_local_and_state_service...
# 4  faculty_and_researcher_national_and_internatio...
# 5  faculty_and_researcher_presentations_and_meeti...
# 6         faculty_and_researcher_scholarly_work_2025
# 7                                 grad_students_2025
# 8                                      post_doc_2025
#
#    has_pub_keyword_anywhere  n_lines  n_blank_lines  likely_non_pub_doc
# 0                      True      472             33               False
# 1                      True      176             41               False
# 2                     False      807             69                True
# 3                     False      380             60                True
# 4                      True      491             73               False
# 5                      True      817             91               False
# 6                      True     1287            125               False
# 7                      True      997            115               False
# 8                      True      463             42               False

# %%
def preview_document(doc_uid: str, max_chars: int = 4000):
    row = df_corpus.loc[df_corpus["doc_uid"] == doc_uid].iloc[0]
    print(row["text_multiline"][:max_chars])

# Set to a doc_uid value to inspect a specific file
example_doc_uid = None

if example_doc_uid:
    preview_document(example_doc_uid)
else:
    print("Set example_doc_uid to inspect a specific document.")
# Out:
# Set example_doc_uid to inspect a specific document.

# %%
STRONG_PUBLICATION_HEADER_PATTERNS = [
    r"publications?",
    r"selected publications?",
    r"selected peer[- ]reviewed publications?",
    r"peer[- ]reviewed publications?",
    r"refereed publications?",
    r"journal articles?",
    r"peer[- ]reviewed journal articles?",
    r"refereed journal articles?",
    r"refereed articles?",
    r"articles in refereed journals?",
    r"book chapters?",
    r"books?\s+and\s+book\s+chapters?",
    r"bibliography",
    r"selected works",
    r"selected scholarly publications?",
    r"peer[- ]reviewed articles?(?:\s+and\s+chapters?)?",
    r"articles?,?\s+chapters?,?\s+and\s+reviews?",
    r"publications?\s+and\s+presentations?",
    r"published manuscripts?",
    r"academic publications?",
    r"scholarly works?",
    r"scholarly activity",
    r"scholarship",
    r"works? published",
    r"creative works?",
    r"monographs?",
    r"edited volumes?",
    r"reports?\s+and\s+publications?",
]

OTHER_SECTION_PATTERNS = [
    r"education",
    r"employment",
    r"academic appointments?",
    r"professional appointments?",
    r"professional experience",
    r"research",
    r"research support",
    r"sponsored research",
    r"grants?",
    r"awards?",
    r"honors?",
    r"teaching",
    r"service",
    r"professional service",
    r"editorial",
    r"editorial service",
    r"presentations?",
    r"conference presentations?",
    r"invited talks?",
    r"talks?",
    r"professional affiliations?",
    r"licensure",
    r"community engagement",
    r"media coverage",
    r"research funding",
    r"funding",
    # NOTE: standalone r"books?" removed — too broad, catches "Book" sub-headers inside pub sections
    r"edited books?",
    r"book reviews?",
    r"encyclopedia entries?",
    r"working papers?",
    r"manuscripts? (?:under review|in progress|in preparation|in prep)",
    r"works? in progress",
    r"research interests?",
    r"research experience",
    r"grants? and contracts?",
    r"fellowships?",
    r"professional activities",
    r"leadership",
    r"mentoring",
    r"training",
    r"media",
    r"outreach",
    r"extension",
    r"consulting"
]

PUB_HEADER_PREFIX_RE = re.compile(
    r"^(?:selected\s+)?(?:peer[- ]reviewed\s+|refereed\s+)?"
    r"(?:publications?|journal articles?|refereed journal articles?|peer[- ]reviewed journal articles?|"
    r"refereed articles?|articles in refereed journals?|book chapters?|books?\s+and\s+book\s+chapters?|"
    r"bibliography|scholarly works?|scholarly activity|scholarship|works? published|creative works?|"
    r"monographs?|edited volumes?|reports?\s+and\s+publications?|selected works|"
    r"selected scholarly publications?|peer[- ]reviewed articles?(?:\s+and\s+chapters?)?|"
    r"articles?,?\s+chapters?,?\s+and\s+reviews?|publications?\s+and\s+presentations?|"
    r"published manuscripts?|academic publications?)"
    r"(?:\s*[:\-\u2013\u2014\u2020\u2021*†].*)?$",
    flags=re.IGNORECASE,
)

OTHER_HEADER_PREFIX_RE = re.compile(
    r"^(?:" + "|".join(OTHER_SECTION_PATTERNS) + r")(?:\s*[:\-\u2013\u2014\u2020\u2021*†].*)?$",
    flags=re.IGNORECASE,
)

YEAR_TOKEN_RE = re.compile(
    r"\b(?:19|20)\d{2}\b|\bin press\b|\bforthcoming\b",
    flags=re.IGNORECASE,
)


def normalize_line(line: str) -> str:
    s = str(line).strip()
    s = re.sub(r"\s+", " ", s)
    return s.strip()


def normalize_header_candidate(line: str) -> str:
    s = normalize_line(line)
    s = re.sub(r"^[\-\u2022\*\d\.\)\(\s]+", "", s)
    s = re.sub(r"\s+", " ", s)
    return s.strip()


def line_is_header_like(line: str) -> bool:
    s = normalize_header_candidate(line)
    if not s:
        return False
    if len(s) > 160:
        return False
    if s.endswith("."):
        return False
    if len(s.split()) > 20:
        return False
    alpha_chars = sum(ch.isalpha() for ch in s)
    if alpha_chars < 4:
        return False
    all_caps = s.upper() == s and alpha_chars >= 4
    titleish = bool(re.fullmatch(r"[A-Z][A-Za-z0-9/&,()'\-\u2013\u2014:* ]+", s))
    return all_caps or titleish


def classify_line(line: str):
    s = normalize_header_candidate(line)
    if not s:
        return None
    if PUB_HEADER_PREFIX_RE.match(s):
        return "publication"
    if OTHER_HEADER_PREFIX_RE.match(s) and line_is_header_like(s):
        return "other"
    return None

# %%
def inspect_candidate_headers(text_multiline: str, max_lines: int = 80) -> pd.DataFrame:
    rows = []
    for i, line in enumerate(text_multiline.split("\n")[:max_lines]):
        raw = line.strip()
        if not raw:
            continue

        rows.append({
            "line_idx": i,
            "raw_line": raw,
            "header_class": classify_line(raw),
            "header_like": line_is_header_like(raw),
        })

    return pd.DataFrame(rows)

for _, row in df_corpus.head(3).iterrows():
    print("\nDOC:", row["doc_uid"])
    display(inspect_candidate_headers(row["text_multiline"], max_lines=80))
# Out:
# DOC: external_faculty_2025
#     line_idx                                           raw_line header_class  \
# 0          0                                      Johari Harris         None
# 1          2                                    HONORS & AWARDS         None
# 2          3  2025 Outstanding Junior Scholar Award, KSU Bag...         None
# 3          4  2025 Outstanding Online Teaching Award, KSU Ba...         None
# 4          5  2025 Outstanding Teaching Award Nomination, SM...         None
# ..       ...                                                ...          ...
# 69        74  o Harris, J., Turner, S & Mitchell, A (2024, N...         None
# 70        75  things!” How Teaching Anti-Bias Units Shifts T...         None
# 71        76  [Panel Presentation]. Association of Middle Le...         None
# 72        77                                         Tennessee.         None
# 73        79                                   GRANTS & FUNDING         None
#
#     header_like
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ..          ...
# 69        False
# 70        False
# 71        False
# 72        False
# 73         True
#
# [74 rows x 4 columns]
# DOC: faculty_and_researcher_awards_and_recognition_2025
#     line_idx                                           raw_line header_class  \
# 0          0                                      Nancy Deutsch         None
# 1          2                                             HONORS        other
# 2          3  • Organizational Award for Excellence in Resea...         None
# 3          4                                   Nex Center) 2024         None
# 4          5              o Society for Research on Adolescence         None
# ..       ...                                                ...          ...
# 60        74                                       John Holbein         None
# 61        76                                             AWARDS        other
# 62        77  • University of Virginia Outstanding Researche...         None
# 63        78  researchers as the best and brightest of the y...         None
# 64        79                                       and awards.”         None
#
#     header_like
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
# ..          ...
# 60         True
# 61         True
# 62        False
# 63        False
# 64        False
#
# [65 rows x 4 columns]
# DOC: faculty_and_researcher_grant_funding_2025
#     line_idx                                           raw_line header_class  \
# 0          0                                      Nancy Deutsch         None
# 1          2             GRANTS AND SPONSORED PROJECTS - FUNDED         None
# 2          3                            • First Tee (2024-2025)         None
# 3          4                    o PGA Tour First Tee Foundation         None
# 4          5          o Sjogren, A. (PI), Deutsch, N.L. (Co-PI)         None
# ..       ...                                                ...          ...
# 71        75  ▪ Collaborative to understand impacts of early...         None
# 72        76  suicide and overdose mortality using data harm...         None
# 73        77                                    1U01MH137067-01         None
# 74        78  ▪ Objective: Integrative Data Analysis of over...         None
# 75        79  prevention. PI: Holly Wilcox, Johns Hopkins pr...         None
#
#     header_like
# 0          True
# 1          True
# 2          True
# 3         False
# 4         False
# ..          ...
# 71        False
# 72        False
# 73        False
# 74        False
# 75        False
#
# [76 rows x 4 columns]

# %%
def extract_all_publication_sections(text_multiline: str):
    '''
    Extract ALL publication sections from a CV, not just the first.
    Returns list of {section_label, section_start_line, section_end_line, section_text}.
    Handles CVs with sub-sections like Peer-Reviewed Articles, Book Chapters, etc.
    '''
    if not isinstance(text_multiline, str) or not text_multiline.strip():
        return []
    lines = text_multiline.split('\n')
    sections = []
    i = 0
    while i < len(lines):
        cls = classify_line(lines[i])
        if cls == 'publication':
            start_line = i
            section_label = normalize_line(lines[i])
            end_line = len(lines)
            for j in range(start_line + 1, len(lines)):
                if classify_line(lines[j]) == 'other':
                    end_line = j
                    break
            section_lines = lines[start_line:end_line]
            section_text = '\n'.join(section_lines).strip()
            nonempty = [ln for ln in section_lines if ln.strip()]
            if len(nonempty) >= 2:
                sections.append({
                    'section_label': section_label,
                    'section_start_line': start_line,
                    'section_end_line': end_line,
                    'section_text': section_text,
                })
            i = end_line
        else:
            i += 1
    return sections

# %%
for _, row in df_corpus.head(5).iterrows():
    sections = extract_all_publication_sections(row['text_multiline'])
    print('DOC:', row['doc_uid'])
    if sections:
        for sec in sections:
            print('SECTION LABEL:', sec['section_label'])
            print('LINE RANGE:', sec['section_start_line'], 'to', sec['section_end_line'])
            print(sec['section_text'][:1400])
            print()
    else:
        print('No publication section found')
    print('\n' + '=' * 100 + '\n')
# Out:
# DOC: external_faculty_2025
# SECTION LABEL: PUBLICATIONS
# LINE RANGE: 14 to 55
# PUBLICATIONS
# • Peer Reviewed Journals
# o Harris, J. (2025) Resisting Silence: Using Developmental Science to Guide
# Conversations Around Race(ism) and Justice in K-12 classrooms. Theory into
# Practice
# o Harris, J., Deutsch, N. L., Cory, M., & Rogers, O. (2025). (Dis) Respect in the M
# (ai) cro Context: Positioning Respect as a Developmental Need of Adolescence.
# Human Development.
# o Harris, J., Darling-Aduana, J., Amoako Kayser, A., Edwards, C., & P. Alridge, D.
# (2025). Examining the impacts of a developmentally appropriate, culturally
# relevant virtual school on student outcomes. Urban Education, 60(4), 896-924.
# DOI: 10.1177/00420859231180139
# o Anderson, E., Darling-Aduana, J., Shapiro, B., Kayser, A. A. A., & Harris, J.
# (2024). Critical Consciousness: Strategies to Humanize Pedagogy in Virtual
# Elementary Classrooms. Distance Learning, 21(3), 69-73.
# o Harris, J., Kruger, A. C., & English, J. (2024). “I Wanna at Least Give Back so
# They Could Have an Idea of Doing Right”: A Culturally Relevant Approach to
# Understanding Black Adolescent Males’ Moral Development. Journal of
# Adolescent Research, 0(0). https://doi.org/10.1177/07435584241268447
# • Book Chapters
# o Harris, J. & Rogers, O. (forthcoming) “I Got A lot to be Mad About” Liberation
# and Social Emotional Learning. In Alridge, D & Chenault, R. (Eds) Liberation
# and Education: Perspectives on Black Educational Thought in America. Rutger
#
# SECTION LABEL: PUBLICATIONS
# LINE RANGE: 126 to 283
# PUBLICATIONS
# • Bentley-Edwards, K. L., & Adams, V. N. Adams, V. N. Adams, V. N. (2024). I am not
# (your) superwoman, Black girl magic, or beautiful struggle: Rethinking the resilience of
# Black women and girls. American Psychologist, 79(8), 1036-1048.
# https://doi.org/10.1037/amp0001304
#
# ACADEMIC PRESENTATIONS
# • 2025 AERA Social Justice and Liberation for Marginalized Communities: "Vicarious
# Black Joy and Fugitive Spaces: The Benefits of Freedom Schools to Black Parents"
# • 2025 Undergraduate Research and Creativity Symposium Moderator. Mass Produced:
# Examining Relationships Between Consumer Culture, Media, and Social Change."
#
# Mimi Arbeit
#
# PUBLICATIONS
# • Arbeit, M. R., Dufault, A. E., Burnham, S. L. F., Onuoha, A. C., Wanjuki, W., & de Four,
# D. (2025). Early intervention against male supremacist influences among college
# students: “It’s really not a program that exists”. Violence Against Women.
# https://doi.org/10.1177/10778012251329186
# • Dufault, A. E., Berger, N. P., & Arbeit, M. R. (2024). College students’ anticipated
# bystander intervention actions against male supremacism: “Something more needs to be
# done”. Journal of Adolescent Research. https://doi.org/10.1177/07435584241297138
# • Marx, R. A., Dufault, A. E., & Arbeit, M. R. (2025). Collective liberation through critical
# pedagogy: Refocusing on queer discovery, joy, and freedom. In L. Baams & T. M. L.
# Kaufman (Eds.), Sexually
#
# SECTION LABEL: PUBLICATIONS
# LINE RANGE: 308 to 398
# PUBLICATIONS
# • Peer Reviewed Publications
# o Bradshaw, C.P., McDaniel, H., Pas, E. T., Debnam, K., J., Bottiani, J., Powell, N.,
# Ialongo, N.S., & Lochman, J. E. (2025).
# Randomized Controlled Trial of the
# Early Adolescent Coping Power Program: Effects on Emotional and
# Behavioral Problems in Middle Schoolers.
# o McDaniel, H., Budavari, L., Tonigan, A., Bradshaw, C., Michael, A. O’Shea, A.,
# Powell, N., Qu, L., Saavedra, L., Yaros,
# A., Lochman, J. & Morgan-López,
# A. (2025). Preventing Suicidal Thoughts and Behaviors Among Youth:
# Longitudinal Crossover
# Impacts of an Externalizing Behavior-
# Focused, School-Based Preventive Intervention.
# JAACAP Open.
# https://doi.org/10.1016/j.jaacop.2025.01.005
# o Budavari, L., McDaniel, H., Morgan-López, A., Musci, R., Downer, J., Ialongo,
# N., & Bradshaw C. (2025). Addressing methodological challenges in follow-up
# RCTs during the COVID-19 pandemic: The impact of the good
# behavior game
#
# and MyTeachingPartnerTM on teacher burnout and self-efficacy. Prevention
# Science.
# https://doi.org/10.1007/s11121-024-01757-9
# o Hernandez, B.*, McDaniel, H. & Bradshaw, C. (2025). Urban Black
# Adolescents’ Victimization Experiences: The
# Moderating Role of Family
# Factors on Internalizing and Academic Outcomes. Journal of Community
# Psychology. https://doi.org/10.1002/jcop.23151
# o Morgan-López, A.A., Saavedra, L.M., McDaniel, H.L., West, S.G., Ialongo, N.S.,
# Bradshaw, C.P., To
#
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_awards_and_recognition_2025
# No publication section found
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_grant_funding_2025
# No publication section found
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_local_and_state_service_2025
# No publication section found
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_national_and_international_service_2025
# No publication section found
#
# ====================================================================================================

# %%
YEAR_RE = r"(?:19|20)\d{2}|in press|forthcoming"
NUMBER_OR_BULLET_RE = re.compile(r"^(?:\[?\d+\]?\.?\s+|[-\u2022*]\s+)")
LEADING_AUTHOR_YEAR_RE = re.compile(
    rf"^(?:[A-Z][A-Za-z'`\-]+(?:,?\s+[A-Z]\.)?(?:,\s*[A-Z]\.)*.+?\b(?:{YEAR_RE})\b)",
    flags=re.IGNORECASE,
)

_HEADER_STRIP_RE = re.compile(
    r"^(?:selected\s+)?(?:peer[- ]reviewed\s+|refereed\s+)?"
    r"(?:publications?|journal articles?|refereed journal articles?|peer[- ]reviewed journal articles?|"
    r"refereed articles?|articles in refereed journals?|book chapters?|books?\s+and\s+book\s+chapters?|"
    r"bibliography|scholarly works?|scholarly activity|scholarship|works? published|creative works?|"
    r"monographs?|edited volumes?|reports?\s+and\s+publications?)"
    r"\s*[:\-\u2013\u2014\u2020\u2021*†]?\s*",
    flags=re.IGNORECASE,
)


def clean_citation_text(text: str) -> str:
    text = re.sub(r"\s+", " ", str(text)).strip()
    text = re.sub(r"^[-\u2022*\s]+", "", text)
    return text


def remove_header_from_section(section_text: str):
    lines = [ln.rstrip() for ln in section_text.split("\n")]
    if not lines:
        return []

    # Strip ALL consecutive pub sub-headers from the top (not just the first).
    # Handles cases like "SCHOLARSHIP\nPEER REVIEWED ARTICLES:\nActual citation..."
    while lines:
        first = normalize_header_candidate(lines[0])
        if classify_line(first) == "publication":
            stripped = _HEADER_STRIP_RE.sub("", lines[0], count=1)
            if stripped.strip():
                lines[0] = stripped
                break  # remainder of line is content, stop stripping
            else:
                lines = lines[1:]  # entire line was a header, remove and continue
        else:
            break

    return [ln.rstrip() for ln in lines]


def _split_block_by_boundaries(block_lines):
    # Split a blank-line block further on number/bullet/author-year boundaries.
    groups = []
    current = []
    for line in block_lines:
        stripped = line.strip()
        if not stripped:
            continue
        starts_new = (
            current
            and (NUMBER_OR_BULLET_RE.match(stripped) or LEADING_AUTHOR_YEAR_RE.match(stripped))
        )
        if starts_new:
            groups.append(current)
            current = [NUMBER_OR_BULLET_RE.sub("", stripped).strip()]
        else:
            if current:
                current.append(stripped)
            else:
                current.append(NUMBER_OR_BULLET_RE.sub("", stripped).strip())
    if current:
        groups.append(current)
    return groups


def split_candidate_citations(section_text: str):
    if not isinstance(section_text, str) or not section_text.strip():
        return []
    content_lines = remove_header_from_section(section_text)
    if not content_lines:
        return []

    blocks = []
    current_block = []
    for line in content_lines:
        if not line.strip():
            if current_block:
                blocks.append(current_block)
                current_block = []
        else:
            current_block.append(line.strip())
    if current_block:
        blocks.append(current_block)

    if len(blocks) > 1:
        entries = []
        for block in blocks:
            for grp in _split_block_by_boundaries(block):
                entries.append(clean_citation_text(" ".join(grp)))
        return [e for e in entries if len(e) >= 25]

    entries = []
    current = []
    for line in content_lines:
        stripped = line.strip()
        if not stripped:
            continue
        starts_new = (
            not current
            or NUMBER_OR_BULLET_RE.match(stripped)
            or LEADING_AUTHOR_YEAR_RE.match(stripped)
        )
        cleaned = NUMBER_OR_BULLET_RE.sub("", stripped).strip()
        if starts_new:
            if current:
                entries.append(clean_citation_text(" ".join(current)))
            current = [cleaned]
        else:
            current.append(cleaned)
    if current:
        entries.append(clean_citation_text(" ".join(current)))
    return [e for e in entries if len(e) >= 25]

# %%
for _, row in df_corpus.head(5).iterrows():
    sections = extract_all_publication_sections(row['text_multiline'])
    print('DOC:', row['doc_uid'])
    if sections:
        for sec in sections:
            citations = split_candidate_citations(sec['section_text'])
            print('SECTION LABEL:', sec['section_label'])
            print('N CANDIDATES:', len(citations))
            for i, citation in enumerate(citations[:3], start=1):
                print(f'\nCitation {i}:')
                print(citation[:500])
            print()
    else:
        print('No publication section found')
    print('\n' + '=' * 100 + '\n')
# Out:
# DOC: external_faculty_2025
# SECTION LABEL: PUBLICATIONS
# N CANDIDATES: 3
#
# Citation 1:
# Peer Reviewed Journals o Harris, J. (2025) Resisting Silence: Using Developmental Science to Guide Conversations Around Race(ism) and Justice in K-12 classrooms. Theory into Practice o Harris, J., Deutsch, N. L., Cory, M., & Rogers, O. (2025). (Dis) Respect in the M (ai) cro Context: Positioning Respect as a Developmental Need of Adolescence. Human Development. o Harris, J., Darling-Aduana, J., Amoako Kayser, A., Edwards, C., & P. Alridge, D. (2025). Examining the impacts of a developmentally ap
#
# Citation 2:
# Book Chapters o Harris, J. & Rogers, O. (forthcoming) “I Got A lot to be Mad About” Liberation and Social Emotional Learning. In Alridge, D & Chenault, R. (Eds) Liberation and Education: Perspectives on Black Educational Thought in America. Rutgers Press o Jagers, R, Williams, B, Harris, J & Coleman, B (forthcoming) Assessing systemic transformative SEL implementation in diverse school communities. In L. Hamilton, D.C. Kidd & S. Rikoon. Promoting K-12 Civic Learning and Engagement through Assess
#
# Citation 3:
# Black Lives. In H.E. Cole, S.C.Pitawanakwat & L.Rocha (Eds.). Mothering and Mother(Work) in the Times of Black Lives Matter. (pp. 167-185). Demeter Press. o Harris, J. Scott, E., Alrdige, D., Deutsch, N & Bradshaw, C (2024) Educating for Democracy: School and Classroom Based Practice. In L. Nucci, T. Krettenauer & W.C. Thompson (Eds). Handbook for Moral and Character Development. Routledge
#
# SECTION LABEL: PUBLICATIONS
# N CANDIDATES: 26
#
# Citation 1:
# Bentley-Edwards, K. L., & Adams, V. N. Adams, V. N. Adams, V. N. (2024). I am not (your) superwoman, Black girl magic, or beautiful struggle: Rethinking the resilience of Black women and girls. American Psychologist, 79(8), 1036-1048. https://doi.org/10.1037/amp0001304
#
# Citation 2:
# 2025 AERA Social Justice and Liberation for Marginalized Communities: "Vicarious Black Joy and Fugitive Spaces: The Benefits of Freedom Schools to Black Parents"
#
# Citation 3:
# 2025 Undergraduate Research and Creativity Symposium Moderator. Mass Produced: Examining Relationships Between Consumer Culture, Media, and Social Change."
#
# SECTION LABEL: PUBLICATIONS
# N CANDIDATES: 11
#
# Citation 1:
# Peer Reviewed Publications o Bradshaw, C.P., McDaniel, H., Pas, E. T., Debnam, K., J., Bottiani, J., Powell, N.,
#
# Citation 2:
# Ialongo, N.S., & Lochman, J. E. (2025). Randomized Controlled Trial of the Early Adolescent Coping Power Program: Effects on Emotional and Behavioral Problems in Middle Schoolers. o McDaniel, H., Budavari, L., Tonigan, A., Bradshaw, C., Michael, A. O’Shea, A., Powell, N., Qu, L., Saavedra, L., Yaros, A., Lochman, J. & Morgan-López, A. (2025). Preventing Suicidal Thoughts and Behaviors Among Youth: Longitudinal Crossover Impacts of an Externalizing Behavior- Focused, School-Based Preventive Inter
#
# Citation 3:
# https://doi.org/10.1016/j.jaacop.2025.01.005 o Budavari, L., McDaniel, H., Morgan-López, A., Musci, R., Downer, J., Ialongo, N., & Bradshaw C. (2025). Addressing methodological challenges in follow-up RCTs during the COVID-19 pandemic: The impact of the good behavior game
#
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_awards_and_recognition_2025
# No publication section found
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_grant_funding_2025
# No publication section found
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_local_and_state_service_2025
# No publication section found
#
# ====================================================================================================
#
# DOC: faculty_and_researcher_national_and_international_service_2025
# No publication section found
#
# ====================================================================================================

# %%
results = []

for _, row in df_corpus.iterrows():
    text_multi = row['text_multiline']
    sections = extract_all_publication_sections(text_multi)
    has_pub_keyword_anywhere = bool(PUB_ANYWHERE_RE.search(text_multi))

    if not sections:
        results.append({
            'doc_uid': row['doc_uid'],
            'doc_id': row['doc_id'],
            'path': row['path'],
            'has_pub_keyword_anywhere': has_pub_keyword_anywhere,
            'section_found': False,
            'section_label': None,
            'section_start_line': None,
            'section_end_line': None,
            'citation_id': None,
            'raw_citation': None,
            'n_candidate_citations': 0,
        })
        continue

    for section_result in sections:
        citations = split_candidate_citations(section_result['section_text'])
        if not citations:
            results.append({
                'doc_uid': row['doc_uid'],
                'doc_id': row['doc_id'],
                'year': row['year'],
                'path': row['path'],
                'has_pub_keyword_anywhere': has_pub_keyword_anywhere,
                'section_found': True,
                'section_label': section_result['section_label'],
                'section_start_line': section_result['section_start_line'],
                'section_end_line': section_result['section_end_line'],
                'citation_id': None,
                'raw_citation': None,
                'n_candidate_citations': 0,
            })
            continue
        for i, citation in enumerate(citations, start=1):
            results.append({
                'doc_uid': row['doc_uid'],
                'doc_id': row['doc_id'],
                'path': row['path'],
                'has_pub_keyword_anywhere': has_pub_keyword_anywhere,
                'section_found': True,
                'section_label': section_result['section_label'],
                'section_start_line': section_result['section_start_line'],
                'section_end_line': section_result['section_end_line'],
                'citation_id': i,
                'raw_citation': citation,
                'n_candidate_citations': len(citations),
            })

df_biblio_candidates = pd.DataFrame(results)
df_biblio_candidates.head(10)
# Out:
#                  doc_uid                 doc_id  \
# 0  external_faculty_2025  external_faculty_2025
# 1  external_faculty_2025  external_faculty_2025
# 2  external_faculty_2025  external_faculty_2025
# 3  external_faculty_2025  external_faculty_2025
# 4  external_faculty_2025  external_faculty_2025
# 5  external_faculty_2025  external_faculty_2025
# 6  external_faculty_2025  external_faculty_2025
# 7  external_faculty_2025  external_faculty_2025
# 8  external_faculty_2025  external_faculty_2025
# 9  external_faculty_2025  external_faculty_2025
#
#                                                 path  \
# 0  /content/youthnex_txt_spaces/external_faculty_...
# 1  /content/youthnex_txt_spaces/external_faculty_...
# 2  /content/youthnex_txt_spaces/external_faculty_...
# 3  /content/youthnex_txt_spaces/external_faculty_...
# 4  /content/youthnex_txt_spaces/external_faculty_...
# 5  /content/youthnex_txt_spaces/external_faculty_...
# 6  /content/youthnex_txt_spaces/external_faculty_...
# 7  /content/youthnex_txt_spaces/external_faculty_...
# 8  /content/youthnex_txt_spaces/external_faculty_...
# 9  /content/youthnex_txt_spaces/external_faculty_...
#
#    has_pub_keyword_anywhere  section_found section_label  section_start_line  \
# 0                      True           True  PUBLICATIONS                14.0
# 1                      True           True  PUBLICATIONS                14.0
# 2                      True           True  PUBLICATIONS                14.0
# 3                      True           True  PUBLICATIONS               126.0
# 4                      True           True  PUBLICATIONS               126.0
# 5                      True           True  PUBLICATIONS               126.0
# 6                      True           True  PUBLICATIONS               126.0
# 7                      True           True  PUBLICATIONS               126.0
# 8                      True           True  PUBLICATIONS               126.0
# 9                      True           True  PUBLICATIONS               126.0
#
#    section_end_line  citation_id  \
# 0              55.0          1.0
# 1              55.0          2.0
# 2              55.0          3.0
# 3             283.0          1.0
# 4             283.0          2.0
# 5             283.0          3.0
# 6             283.0          4.0
# 7             283.0          5.0
# 8             283.0          6.0
# 9             283.0          7.0
#
#                                         raw_citation  n_candidate_citations
# 0  Peer Reviewed Journals o Harris, J. (2025) Res...                      3
# 1  Book Chapters o Harris, J. & Rogers, O. (forth...                      3
# 2  Black Lives. In H.E. Cole, S.C.Pitawanakwat & ...                      3
# 3  Bentley-Edwards, K. L., & Adams, V. N. Adams, ...                     26
# 4  2025 AERA Social Justice and Liberation for Ma...                     26
# 5  2025 Undergraduate Research and Creativity Sym...                     26
# 6  Arbeit, M. R., Dufault, A. E., Burnham, S. L. ...                     26
# 7  Dufault, A. E., Berger, N. P., & Arbeit, M. R....                     26
# 8  Marx, R. A., Dufault, A. E., & Arbeit, M. R. (...                     26
# 9                 RESEARCH GRANTS & EXTERNAL FUNDING                     26

# %%
def citation_quality_flag(text: str) -> str:
    if not isinstance(text, str) or not text.strip():
        return "missing"

    lowered = text.lower()
    has_year = bool(re.search(r"\b(?:19|20)\d{2}\b|\bin press\b|\bforthcoming\b", lowered))
    too_short = len(text) < 40
    too_long = len(text) > 1200

    if too_short:
        return "too_short"
    if too_long:
        return "too_long"
    if not has_year:
        return "no_year_found"
    return "ok"


df_biblio_candidates["citation_quality_flag"] = (
    df_biblio_candidates["raw_citation"].apply(citation_quality_flag)
)

print("Files loaded:", len(df_corpus))
print("Unique documents (doc_uid):", df_corpus["doc_uid"].nunique())
print(
    "Documents with publication-like keyword anywhere:",
    df_biblio_candidates.loc[df_biblio_candidates["has_pub_keyword_anywhere"], "doc_uid"].nunique()
)
print(
    "Documents with section found:",
    df_biblio_candidates.loc[df_biblio_candidates["section_found"], "doc_uid"].nunique()
)
print(
    "Total candidate citation rows:",
    df_biblio_candidates["raw_citation"].notna().sum()
)

print("\nTop detected section labels")
display(
    df_biblio_candidates
    .groupby("section_label", dropna=False)
    .size()
    .sort_values(ascending=False)
    .head(20)
    .to_frame("n_rows")
)

print("\nCitation quality flags")
display(
    df_biblio_candidates
    .groupby("citation_quality_flag", dropna=False)
    .size()
    .sort_values(ascending=False)
    .to_frame("n_rows")
)
# Out:
# Files loaded: 9
# Unique documents (doc_uid): 9
# Documents with publication-like keyword anywhere: 7
# Documents with section found: 4
# Total candidate citation rows: 549
#
# Top detected section labels
#                                 n_rows
# section_label
# PUBLICATIONS                       185
# REFEREED JOURNAL ARTICLES          160
# PEER REVIEWED PUBLICATIONS          88
# BOOK CHAPTERS                       65
# REFEREED ARTICLES                   29
# ACADEMIC PUBLICATIONS                9
# BOOK CHAPTER                         6
# SCHOLARSHIP                          5
# NaN                                  5
# PEER-REVIEWED JOURNAL ARTICLES       2
# Citation quality flags
#                        n_rows
# citation_quality_flag
# ok                        377
# no_year_found             125
# too_short                  42
# missing                     5
# too_long                    5

# %%
sample_sections = (
    df_biblio_candidates.loc[df_biblio_candidates["section_found"], ["doc_uid", "section_label"]]
    .drop_duplicates()
    .head(25)
)
sample_sections
# Out:
#                                         doc_uid  \
# 0                         external_faculty_2025
# 45   faculty_and_researcher_scholarly_work_2025
# 126  faculty_and_researcher_scholarly_work_2025
# 150  faculty_and_researcher_scholarly_work_2025
# 351  faculty_and_researcher_scholarly_work_2025
# 380  faculty_and_researcher_scholarly_work_2025
# 386                          grad_students_2025
# 391                          grad_students_2025
# 452                          grad_students_2025
# 454                          grad_students_2025
# 456                          grad_students_2025
# 509                               post_doc_2025
# 523                               post_doc_2025
#
#                       section_label
# 0                      PUBLICATIONS
# 45       PEER REVIEWED PUBLICATIONS
# 126       REFEREED JOURNAL ARTICLES
# 150                   BOOK CHAPTERS
# 351               REFEREED ARTICLES
# 380                    BOOK CHAPTER
# 386                     SCHOLARSHIP
# 391                    PUBLICATIONS
# 452      PEER REVIEWED PUBLICATIONS
# 454  PEER-REVIEWED JOURNAL ARTICLES
# 456           ACADEMIC PUBLICATIONS
# 509                    PUBLICATIONS
# 523      PEER REVIEWED PUBLICATIONS

# %%
needs_review_no_section = (
    df_biblio_candidates[
        (df_biblio_candidates["has_pub_keyword_anywhere"]) &
        (~df_biblio_candidates["section_found"])
    ][["doc_uid", "path"]]
    .drop_duplicates()
)

needs_review_no_citations = (
    df_biblio_candidates[
        (df_biblio_candidates["section_found"]) &
        (df_biblio_candidates["n_candidate_citations"] == 0)
    ][["doc_uid", "path", "section_label"]]
    .drop_duplicates()
)

problem_citations = (
    df_biblio_candidates[
        df_biblio_candidates["citation_quality_flag"].isin(["too_short", "too_long"])
    ][["doc_uid", "citation_id", "citation_quality_flag", "raw_citation"]]
)

print("Needs review - pub keyword but no section:", len(needs_review_no_section))
print("Needs review - section but no citations:", len(needs_review_no_citations))
print("Problem citations:", len(problem_citations))
# Out:
# Needs review - pub keyword but no section: 3
# Needs review - section but no citations: 0
# Problem citations: 47

# %%
needs_review_no_section.head(20)
# Out:
#                                               doc_uid  \
# 40  faculty_and_researcher_awards_and_recognition_...
# 43  faculty_and_researcher_national_and_internatio...
# 44  faculty_and_researcher_presentations_and_meeti...
#
#                                                  path
# 40  /content/youthnex_txt_spaces/faculty_and_resea...
# 43  /content/youthnex_txt_spaces/faculty_and_resea...
# 44  /content/youthnex_txt_spaces/faculty_and_resea...

# %%
needs_review_no_citations.head(20)
# Out:
# Empty DataFrame
# Columns: [doc_uid, path, section_label]
# Index: []

# %%
problem_citations.head(20)
# Out:
#                                         doc_uid  citation_id  \
# 9                         external_faculty_2025          7.0
# 21                        external_faculty_2025         19.0
# 27                        external_faculty_2025         25.0
# 36                        external_faculty_2025          8.0
# 82   faculty_and_researcher_scholarly_work_2025         38.0
# 97   faculty_and_researcher_scholarly_work_2025         53.0
# 103  faculty_and_researcher_scholarly_work_2025         59.0
# 105  faculty_and_researcher_scholarly_work_2025         61.0
# 123  faculty_and_researcher_scholarly_work_2025         79.0
# 140  faculty_and_researcher_scholarly_work_2025         15.0
# 145  faculty_and_researcher_scholarly_work_2025         20.0
# 153  faculty_and_researcher_scholarly_work_2025          4.0
# 169  faculty_and_researcher_scholarly_work_2025         20.0
# 188  faculty_and_researcher_scholarly_work_2025         39.0
# 196  faculty_and_researcher_scholarly_work_2025         47.0
# 206  faculty_and_researcher_scholarly_work_2025         57.0
# 220  faculty_and_researcher_scholarly_work_2025          6.0
# 221  faculty_and_researcher_scholarly_work_2025          7.0
# 223  faculty_and_researcher_scholarly_work_2025          9.0
# 279  faculty_and_researcher_scholarly_work_2025         65.0
#
#     citation_quality_flag                                       raw_citation
# 9               too_short                 RESEARCH GRANTS & EXTERNAL FUNDING
# 21               too_long  Peer-Reviewed Journal Articles o Scott, E., Ga...
# 27              too_short                        Leath, S. (2024, November).
# 36               too_long  https://doi.org/10.1080/2372966X.2022.2100275 ...
# 82              too_short                CHAPTERS & PAPERS IN EDITED VOLUMES
# 97              too_short                     PEER REVIEWED JOURNAL ARTICLES
# 103             too_short                        PEER REVIEWED BOOK CHAPTERS
# 105             too_short                          NON-REFEREED PUBLICATIONS
# 123             too_short               https://doi.org/10.3390/youth4020032
# 140             too_short                     PEER-REVIEWED JOURNAL ARTICLES
# 145             too_short                 JOURNAL ARTICLES UNDER PEER REVIEW
# 153             too_short                        INVITED REPORTS AND REVIEWS
# 169             too_short                     PEER REVIEWED JOURNAL ARTICLES
# 188             too_short                        PEER REVIEWED BOOK CHAPTERS
# 196             too_short                         WORKS IN REFEREED JOURNALS
# 206             too_short                   EVALUATIONS & OTHER PUBLICATIONS
# 220             too_short                https:// doi.org/10.1037/spq0000616
# 221             too_short             REFEREED JOURNAL ARTICLES UNDER REVIEW
# 223             too_short                         PEER-REVIEWED PUBLICATIONS
# 279             too_short                          REFEREED JOURNAL ARTICLES

# %%
## define export folder in local Colab
EXPORT_DIR = Path("/content/biblio_exports")
EXPORT_DIR.mkdir(parents=True, exist_ok=True)

## file paths
candidate_path    = EXPORT_DIR / f"{EXPORT_PREFIX}_candidate_citations.csv"
no_section_path   = EXPORT_DIR / f"{EXPORT_PREFIX}_needs_review_no_section.csv"
no_citations_path = EXPORT_DIR / f"{EXPORT_PREFIX}_needs_review_no_citations.csv"
problem_path      = EXPORT_DIR / f"{EXPORT_PREFIX}_problem_citations.csv"

## Exclude rows with no citation text before export
df_export = df_biblio_candidates[
    df_biblio_candidates["citation_quality_flag"] != "missing"
].copy()

## save files
df_export.to_csv(candidate_path, index=False)
needs_review_no_section.to_csv(no_section_path, index=False)
needs_review_no_citations.to_csv(no_citations_path, index=False)
problem_citations.to_csv(problem_path, index=False)

## summary
print("Saved to:", EXPORT_DIR)
print("-", candidate_path.name, f"({len(df_export):,} rows, {len(df_biblio_candidates) - len(df_export)} missing rows excluded)")
print("-", no_section_path.name)
print("-", no_citations_path.name)
print("-", problem_path.name)
# Out:
# Saved to: /content/biblio_exports
# - biblio_stabilized_candidate_citations.csv (549 rows, 5 missing rows excluded)
# - biblio_stabilized_needs_review_no_section.csv
# - biblio_stabilized_needs_review_no_citations.csv
# - biblio_stabilized_problem_citations.csv

# %% [markdown]
# ## Deduplication

# %%
## local Colab paths
DEDUP_INPUT_PATH = Path("/content/biblio_exports/biblio_stabilized_candidate_citations.csv")

DEDUP_EXPORT_DIR = Path("/content/dedup_exports")
DEDUP_EXPORT_DIR.mkdir(parents=True, exist_ok=True)

DEDUP_OUTPUT_PATH = DEDUP_EXPORT_DIR / "deduplicated_citations.csv"


def load_and_clean_citations(file_path, column_name="raw_citation",
                             output_path="deduplicated_citations.csv", show_stats=True):
    """
    Load a CSV file and return cleaned, filtered citations.

    Parameters:
        file_path (str): Path to the CSV file
        column_name (str): Name of the column containing citations

    Returns:
        citations (pd.Series): Filtered original citations
        citations_clean (pd.Series): Cleaned citations
    """

    ### Load data
    df = pd.read_csv(file_path, low_memory=False)

    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in CSV")

    citations = df[column_name].dropna().reset_index(drop=True)

    ### Filter invalid citations
    def is_valid_citation(text):
        text = str(text).lower().strip()

        # Remove very short entries
        if len(text.split()) < 5:
            return False

        bad_patterns = [
            "book chapter",
            "book chapters",
            "publications",
            "references",
            "bibliography",
            "refereed",
            "journal articles",
            "peer reviewed",
            "peer reviewed",
            "awarded",
            "granted",
            "grants",
            "under review",
            "appearances",
            "internship"
        ]

        if any(p in text for p in bad_patterns):
            return False

        return True

    citations = citations[citations.apply(is_valid_citation)].reset_index(drop=True)

    ### Clean text
    def clean_citation(text):
        text = str(text).lower()

        ### Remove punctuation
        text = re.sub(r'[^\w\s]', ' ', text)

        ### Collapse whitespace
        text = re.sub(r'\s+', ' ', text)

        return text.strip()

    citations_clean = citations.apply(clean_citation)

    vectorizer = TfidfVectorizer(
        stop_words="english",
        max_features=5000   # prevents noise explosion
    )

    X = vectorizer.fit_transform(citations_clean)

    nn = NearestNeighbors(metric="cosine", n_neighbors=5)
    nn.fit(X)

    distances, indices = nn.kneighbors(X)

    threshold = 0.15  # distance (cosine distance = 1 - similarity)

    groups = []
    visited = set()

    for i in range(len(citations)):
        if i in visited:
            continue

        group = [i]

        for j, dist in zip(indices[i], distances[i]):
            if j != i and dist < threshold:
                group.append(j)
                visited.add(j)

        visited.add(i)

        if len(group) > 1:
            groups.append(group)

    unique_indices = set(range(len(citations)))

    for group in groups:
        for idx in group[1:]:  # keep first, remove rest
            unique_indices.discard(idx)

    unique_citations = citations.iloc[list(unique_indices)]
    df_unique = pd.DataFrame({
        "citation": unique_citations.reset_index(drop=True)
    })

    df_unique["num_words"] = df_unique["citation"].apply(lambda x: len(x.split()))
    df_unique["num_chars"] = df_unique["citation"].apply(len)

    min_words = 20
    min_chars = 100

    df_filtered = df_unique[
        (df_unique["num_words"] >= min_words) &
        (df_unique["num_chars"] >= min_chars)
    ].reset_index(drop=True)

    df_filtered.to_csv(output_path, index=False)
    updated_citations = df_filtered["citation"]

    if show_stats:

        # How much redundancy was there before,
        # And how much we cleaned it
        total = len(citations)
        unique = len(df_filtered)
        duplicates_removed = total - unique
        reduction_pct = (duplicates_removed / total) * 100

        print(f"Total citations: {total}")
        print(f"Unique citations: {unique}")
        print(f"Duplicates removed: {duplicates_removed}")
        print(f"Reduction: {reduction_pct:.2f}%")

        print('')
        print('=========================================================')
        print('')

        # Visualization for before and after
        plt.figure()
        plt.bar(["Original", "Unique"], [total, unique])
        plt.title("Deduplication Impact")
        plt.ylabel("Number of Citations")
        plt.show()

        print('')
        print('=========================================================')
        print('')

        # Visualization for group distributions
        group_sizes = [len(g) for g in groups]

        plt.figure()
        plt.hist(group_sizes, bins=10)
        plt.title("Duplicate Group Sizes")
        plt.xlabel("Group Size")
        plt.ylabel("Frequency")
        plt.show()

        print('')
        print('=========================================================')
        print('')
        # Largest duplicate groups
        top_references = []

        for group in groups:
            representative = citations.iloc[group[0]]
            count = len(group)

            top_references.append({
                "citation": representative,
                "count": count
            })

        top_refs_df = pd.DataFrame(top_references)
        top_refs_df = top_refs_df.sort_values("count", ascending=False)

        print("\nMost Reused Citations:\n")
        filtered_citations = top_refs_df[
            top_refs_df["citation"].notna() &
            (top_refs_df["citation"].str.len() >= 100)
        ]["citation"].head(10)

        print("\n\n".join(filtered_citations))

        print('')
        print('=========================================================')
        print('')

        # Function to extract and identify the most prolific authors
        def extract_author(citation):
            return citation.split(",")[0].strip()

        df_filtered["author"] = df_unique["citation"].apply(extract_author)

        top_authors = df_filtered["author"].value_counts().head(10)

        # Visualization
        top_authors.plot(kind="bar")
        plt.title("Top 10 Most Frequent Authors")
        plt.ylabel("Number of Citations")
        plt.xticks(rotation=45)
        plt.show()

        print('')
        print('=========================================================')
        print('')

        print(top_authors)

        print('')
        print('=========================================================')
        print('')

        # How often are citations reused across different CVs
        reuse_counts = [len(g) for g in groups]

        avg_reuse = round(sum(reuse_counts) / len(reuse_counts), 3)

        print("Average reuse per duplicated citation:", avg_reuse)

        # Are most citations unique or shared?
        num_repeated = sum(1 for g in groups if len(g) > 1)
        num_singletons = unique - num_repeated

        print("Unique single-use citations:", num_singletons)
        print("Repeated citations:", num_repeated)

        # Citations that were too short or sus

        df_filtered["num_words"] = df_filtered["citation"].apply(lambda x: len(x.split()))
        short_citations = df_filtered[df_filtered["num_words"] < 15]
        print("Potential low-quality citations:", len(short_citations))

        # Vocabulary size (before and after)
        original_vocab = len(set(" ".join(citations).lower().split()))
        unique_vocab = len(set(" ".join(df_unique["citation"]).lower().split()))

        print("Original vocab size:", original_vocab)
        print("Unique vocab size:", unique_vocab)




    return output_path

# %%
load_and_clean_citations(
    '/content/biblio_exports/biblio_stabilized_candidate_citations.csv',
    output_path='/content/dedup_exports/dedup_citations.csv',
    show_stats=True
)
# Out:
# Total citations: 408
# Unique citations: 296
# Duplicates removed: 112
# Reduction: 27.45%
#
# =========================================================
# =========================================================
# =========================================================
#
#
# Most Reused Citations:
#
# Lyons, M. D., Zabek, F., Grimes, T. O., Downey, S., Taylor, J. V., & Zeanah, K. L. (in press). Applying the Extension for Community Healthcare Outcomes (ECHO) model to promote collaborative and effective school mental health services. School Psychology, 39(4), 407–418. https://doi.org/10.1037/spq0000616
#
# Pandey, T., Voegtlin, R., Rouiller, S., Pas, E.T., Debnam, K.J., & Bradshaw, C. (2024). A research-practice partnership to develop the R-CITY multi-component equity-focused social emotional learning intervention. School Mental Health. https://doi.org/10.1007/s12310-024-09703-4
#
# Debnam, K. J., Kaihoi, C.A., Pas, E. T., & Bradshaw, C. P. (2024). A School-wide Approach to cultural responsivity and student engagement: A randomized trial of Double Check in middle schools. Journal of School Psychology, 107.
#
# Downer, J., Braun, S.S., Bradshaw, C.P., Elreda, L., Ialongo, N.S., & Tolan, N. (2024). Testing the Combined Effects of the PAX Good Behavior Game and MyTeachingPartnerTM coaching for early career teachers: Impacts on teacher-student interaction quality and teachers’ occupational health. Journal of School Psychology, 106.
#
# Michael, K., & Bradshaw, C.P. (2024). Coping Power – Rural: Iterative adaptation of an evidence-based preventive intervention for rural upper elementary and middle schools. Journal of School Mental Health. https://doi.org/10.1007/s12310-024-09632-2
#
# Bradshaw, C.P. (2024). The CARES Classroom Observation Tool: Psychometrics of an observational measure of culturally responsive practices. Journal of School Psychology.
#
# Beahm, L. A., Hersch, J., Pérez, P., Bush, F., Hughes, B., Nguyen, A., & Bradshaw, C.P. (in press). Collaborating with schools to implement Coping Power-Rural. In B. Cook & T. Landrum (Eds.). Advances in Learning and Behavioral Disabilities. Emerald.
#
# Lindstrom Johnson, S., Pas. E., Debnam, K.J., †Kaihoi, C.A., & Bradshaw, C. P. (2024). Effects of an MTSS-B intervention on student and staff perceptions of school climate: Findings from two group randomized trials. School Psychology Review. DOI: 10.1080/2372966X.2022.2142954
#
# Lyons, M. D., Meldrum, M., Simon, D., Griffith, A., Sjogren, A. L., & Zabek, F. A. (accepted). Coordinating Mental Health Supports Across Out-of-School and In-School o Providers: A Scoping Review. Education Sciences,
#
# Quiles, T.B., Mathews, C., *Ross, R.A., *Rosario, M., & Leath, S (2024). A quantitative investigation of Black and Latina adolescent girls’ experiences of gendered racial microaggressions, familial racial socialization, and critical action. Youth, 4(2), 454-
#
# =========================================================
# =========================================================
#
# author
# Bradshaw           9
# Henderson Smith    9
# Debnam             8
# Johnson            7
# Wahl               6
# Jennings           5
# Unlu               4
# Bottiani           4
# Rivens             4
# Sequeira           4
# Name: count, dtype: int64
#
# =========================================================
#
# Average reuse per duplicated citation: 2.2
# Unique single-use citations: 276
# Repeated citations: 20
# Potential low-quality citations: 0
# Original vocab size: 3509
# Unique vocab size: 3492
# '/content/dedup_exports/dedup_citations.csv'

# %%
df_biblio = pd.read_csv(
    "/content/biblio_exports/biblio_stabilized_candidate_citations.csv",
    low_memory=False
)

len(df_biblio)
# Out:
# 549

# %%
df_unique = pd.read_csv("/content/dedup_exports/dedup_citations.csv")
print(df_unique.columns)
df_unique.head()

from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet

pdf_path = "/content/dedup_exports/bibliography_clean.pdf"

doc = SimpleDocTemplate(pdf_path)
styles = getSampleStyleSheet()
elements = []

elements.append(Paragraph("Estimated Deduplicated Bibliography", styles["Title"]))
elements.append(Spacer(1, 20))

for i, citation in enumerate(df_unique["citation"], start=1):
    elements.append(Paragraph(f"{i}. {citation}", styles["Normal"]))
    elements.append(Spacer(1, 12))

doc.build(elements)

print("Saved PDF:", pdf_path)
# Out:
# Index(['citation', 'num_words', 'num_chars'], dtype='object')
# Saved PDF: /content/dedup_exports/bibliography_clean.pdf
